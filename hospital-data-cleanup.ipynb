# %%
import urllib.request as request
import json

# %%
with request.urlopen('https://services7.arcgis.com/LXCny1HyhQCUSueu/arcgis/rest/services/Definitive_Healthcare_USA_Hospital_Beds/FeatureServer/0/query?where=STATE_NAME+%3D+%27Colorado%27&outFields=*&outSR=4326&f=json') as response:
    source = response.read()
    data = json.loads(source)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'geometryType', 'spatialReference', 'fields', 'features'])

# %%
data
# Out:
# {'objectIdFieldName': 'OBJECTID',
#  'uniqueIdField': {'name': 'OBJECTID', 'isSystemMaintained': True},
#  'globalIdFieldName': '',
#  'geometryType': 'esriGeometryPoint',
#  'spatialReference': {'wkid': 4326, 'latestWkid': 4326},
#  'fields': [{'name': 'OBJECTID',
#    'type': 'esriFieldTypeOID',
#    'alias': 'OBJECTID',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HOSPITAL_NAME',
#    'type': 'esriFieldTypeString',
#    'alias': 'Hospital Name',
#    'sqlType': 'sqlTypeOther',
#    'length': 1000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HOSPITAL_TYPE',
#    'type': 'esriFieldTypeString',
#    'alias': 'Hospital Type',
#    'sqlType': 'sqlTypeOther',
#    'length': 1000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HQ_ADDRESS',
#    'type': 'esriFieldTypeString',
#    'alias': 'Address',
#    'sqlType': 'sqlTypeOther',
#    'length': 1000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HQ_ADDRESS1',
#    'type': 'esriFieldTypeString',
#    'alias': 'Address Ln2',
#    'sqlType': 'sqlTypeOther',
#    'length': 1000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HQ_CITY',
#    'type': 'esriFieldTypeString',
#    'alias': 'City',
#    'sqlType': 'sqlTypeOther',
#    'length': 1000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HQ_STATE',
#    'type': 'esriFieldTypeString',
#    'alias': 'State Abrv',
#    'sqlType': 'sqlTypeOther',
#    'length': 1000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'HQ_ZIP_CODE',
#    'type': 'esriFieldTypeString',
#    'alias': 'Zip Code',
#    'sqlType': 'sqlTypeOther',
#    'length': 20,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'COUNTY_NAME',
#    'type': 'esriFieldTypeString',
#    'alias': 'County Name',
#    'sqlType': 'sqlTypeOther',
#    'length': 32,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'STATE_NAME',
#    'type': 'esriFieldTypeString',
#    'alias': 'State Name',
#    'sqlType': 'sqlTypeOther',
#    'length': 35,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'STATE_FIPS',
#    'type': 'esriFieldTypeString',
#    'alias': 'State FIPS',
#    'sqlType': 'sqlTypeOther',
#    'length': 2,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'CNTY_FIPS',
#    'type': 'esriFieldTypeString',
#    'alias': 'County FIPS',
#    'sqlType': 'sqlTypeOther',
#    'length': 3,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'FIPS',
#    'type': 'esriFieldTypeString',
#    'alias': 'FIPS',
#    'sqlType': 'sqlTypeOther',
#    'length': 5,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'NUM_LICENSED_BEDS',
#    'type': 'esriFieldTypeInteger',
#    'alias': '# of Licensed Beds',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'NUM_STAFFED_BEDS',
#    'type': 'esriFieldTypeInteger',
#    'alias': '# of Staffed Beds',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'NUM_ICU_BEDS',
#    'type': 'esriFieldTypeInteger',
#    'alias': '# of ICU Beds',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'ADULT_ICU_BEDS',
#    'type': 'esriFieldTypeInteger',
#    'alias': '# of Adult ICU Beds',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'PEDI_ICU_BEDS',
#    'type': 'esriFieldTypeSingle',
#    'alias': '# of Pediatric ICU Beds',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'BED_UTILIZATION',
#    'type': 'esriFieldTypeSingle',
#    'alias': 'Bed Utilization Rate',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Potential_Increase_In_Bed_Capac',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'Potential Increase in Bed Capacity',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'AVG_VENTILATOR_USAGE',
#    'type': 'esriFieldTypeSingle',
#    'alias': 'Average Ventilator Usage',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None}],
#  'features': [{'attributes': {'OBJECTID': 585,
#     'HOSPITAL_NAME': 'Platte Valley Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1600 Prairie Center Pkwy',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Brighton',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80601',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 98,
#     'NUM_STAFFED_BEDS': 89,
#     'NUM_ICU_BEDS': 8,
#     'ADULT_ICU_BEDS': 8,
#     'PEDI_ICU_BEDS': 16,
#     'BED_UTILIZATION': 0.3365245,
#     'Potential_Increase_In_Bed_Capac': 9,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -104.76863899999995, 'y': 39.963935400000025}},
#   {'attributes': {'OBJECTID': 586,
#     'HOSPITAL_NAME': 'UCHealth University of Colorado Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '12605 E 16th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Aurora',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80045',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 698,
#     'NUM_STAFFED_BEDS': 650,
#     'NUM_ICU_BEDS': 144,
#     'ADULT_ICU_BEDS': 144,
#     'PEDI_ICU_BEDS': 50,
#     'BED_UTILIZATION': 0.8355469,
#     'Potential_Increase_In_Bed_Capac': 48,
#     'AVG_VENTILATOR_USAGE': 20},
#    'geometry': {'x': -104.84202879999998, 'y': 39.742629400000055}},
#   {'attributes': {'OBJECTID': 587,
#     'HOSPITAL_NAME': 'North Suburban Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '9191 Grant St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Thornton',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80229',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 157,
#     'NUM_STAFFED_BEDS': 127,
#     'NUM_ICU_BEDS': 16,
#     'ADULT_ICU_BEDS': 16,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.5709201,
#     'Potential_Increase_In_Bed_Capac': 30,
#     'AVG_VENTILATOR_USAGE': 5},
#    'geometry': {'x': -104.98570889999996, 'y': 39.86355510000004}},
#   {'attributes': {'OBJECTID': 588,
#     'HOSPITAL_NAME': 'Childrens Hospital Colorado - Anschutz Medical Campus',
#     'HOSPITAL_TYPE': 'Childrens Hospital',
#     'HQ_ADDRESS': '13123 E 16th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Aurora',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80045',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 444,
#     'NUM_STAFFED_BEDS': 434,
#     'NUM_ICU_BEDS': 36,
#     'ADULT_ICU_BEDS': 36,
#     'PEDI_ICU_BEDS': 82,
#     'BED_UTILIZATION': 0.6275822,
#     'Potential_Increase_In_Bed_Capac': 10,
#     'AVG_VENTILATOR_USAGE': 5},
#    'geometry': {'x': -104.83493109999995, 'y': 39.74224950000007}},
#   {'attributes': {'OBJECTID': 589,
#     'HOSPITAL_NAME': 'SLV Health Regional Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '106 Blanca Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Alamosa',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81101',
#     'COUNTY_NAME': 'Alamosa',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '003',
#     'FIPS': '08003',
#     'NUM_LICENSED_BEDS': 49,
#     'NUM_STAFFED_BEDS': 49,
#     'NUM_ICU_BEDS': 6,
#     'ADULT_ICU_BEDS': 6,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3779145,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.88288599999998, 'y': 37.47247870000007}},
#   {'attributes': {'OBJECTID': 590,
#     'HOSPITAL_NAME': 'The Medical Center of Aurora - Main Campus',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1501 S Potomac St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Aurora',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80012',
#     'COUNTY_NAME': 'Arapahoe',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '005',
#     'FIPS': '08005',
#     'NUM_LICENSED_BEDS': 346,
#     'NUM_STAFFED_BEDS': 309,
#     'NUM_ICU_BEDS': 45,
#     'ADULT_ICU_BEDS': 45,
#     'PEDI_ICU_BEDS': 14,
#     'BED_UTILIZATION': 0.6766432,
#     'Potential_Increase_In_Bed_Capac': 37,
#     'AVG_VENTILATOR_USAGE': 8},
#    'geometry': {'x': -104.83174179999997, 'y': 39.688603700000044}},
#   {'attributes': {'OBJECTID': 591,
#     'HOSPITAL_NAME': 'Swedish Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '501 E Hampden Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Englewood',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80113',
#     'COUNTY_NAME': 'Arapahoe',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '005',
#     'FIPS': '08005',
#     'NUM_LICENSED_BEDS': 408,
#     'NUM_STAFFED_BEDS': 327,
#     'NUM_ICU_BEDS': 58,
#     'ADULT_ICU_BEDS': 58,
#     'PEDI_ICU_BEDS': 17,
#     'BED_UTILIZATION': 0.7616182,
#     'Potential_Increase_In_Bed_Capac': 81,
#     'AVG_VENTILATOR_USAGE': 10},
#    'geometry': {'x': -104.98071769999996, 'y': 39.65417030000003}},
#   {'attributes': {'OBJECTID': 592,
#     'HOSPITAL_NAME': 'Sky Ridge Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '10101 Ridgegate Pkwy',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Lone Tree',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80124',
#     'COUNTY_NAME': 'Douglas',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '035',
#     'FIPS': '08035',
#     'NUM_LICENSED_BEDS': 284,
#     'NUM_STAFFED_BEDS': 284,
#     'NUM_ICU_BEDS': 30,
#     'ADULT_ICU_BEDS': 30,
#     'PEDI_ICU_BEDS': 28,
#     'BED_UTILIZATION': 0.5273714,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 4},
#    'geometry': {'x': -104.87121199999996, 'y': 39.52909900000003}},
#   {'attributes': {'OBJECTID': 593,
#     'HOSPITAL_NAME': 'Littleton Adventist Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '7700 S Broadway',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Littleton',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80122',
#     'COUNTY_NAME': 'Arapahoe',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '005',
#     'FIPS': '08005',
#     'NUM_LICENSED_BEDS': 231,
#     'NUM_STAFFED_BEDS': 159,
#     'NUM_ICU_BEDS': 24,
#     'ADULT_ICU_BEDS': 24,
#     'PEDI_ICU_BEDS': 14,
#     'BED_UTILIZATION': 0.6603946,
#     'Potential_Increase_In_Bed_Capac': 72,
#     'AVG_VENTILATOR_USAGE': 4},
#    'geometry': {'x': -104.98610399999995, 'y': 39.57628840000007}},
#   {'attributes': {'OBJECTID': 594,
#     'HOSPITAL_NAME': 'Pagosa Springs Medical Center (FKA Pagosa Mountain Hospital)',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '95 S Pagosa Blvd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Pagosa Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81147',
#     'COUNTY_NAME': 'Archuleta',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '007',
#     'FIPS': '08007',
#     'NUM_LICENSED_BEDS': 11,
#     'NUM_STAFFED_BEDS': 11,
#     'NUM_ICU_BEDS': 2,
#     'ADULT_ICU_BEDS': 2,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2956413,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -107.07913699999995, 'y': 37.252142900000024}},
#   {'attributes': {'OBJECTID': 595,
#     'HOSPITAL_NAME': 'Good Samaritan Medical Center (FKA Exempla Good Samaritan Medical Center LLC)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '200 Exempla Cir',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Lafayette',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80026',
#     'COUNTY_NAME': 'Boulder',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '013',
#     'FIPS': '08013',
#     'NUM_LICENSED_BEDS': 234,
#     'NUM_STAFFED_BEDS': 183,
#     'NUM_ICU_BEDS': 24,
#     'ADULT_ICU_BEDS': 24,
#     'PEDI_ICU_BEDS': 12,
#     'BED_UTILIZATION': 0.6969234,
#     'Potential_Increase_In_Bed_Capac': 51,
#     'AVG_VENTILATOR_USAGE': 6},
#    'geometry': {'x': -105.08652149999995, 'y': 39.970519000000024}},
#   {'attributes': {'OBJECTID': 596,
#     'HOSPITAL_NAME': 'Avista Adventist Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '100 Health Park Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Louisville',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80027',
#     'COUNTY_NAME': 'Boulder',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '013',
#     'FIPS': '08013',
#     'NUM_LICENSED_BEDS': 114,
#     'NUM_STAFFED_BEDS': 108,
#     'NUM_ICU_BEDS': 8,
#     'ADULT_ICU_BEDS': 8,
#     'PEDI_ICU_BEDS': 26,
#     'BED_UTILIZATION': 0.3495434,
#     'Potential_Increase_In_Bed_Capac': 6,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.15174619999999, 'y': 39.951933300000064}},
#   {'attributes': {'OBJECTID': 597,
#     'HOSPITAL_NAME': 'Longmont United Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1950 Mountain View Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Longmont',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80501',
#     'COUNTY_NAME': 'Boulder',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '013',
#     'FIPS': '08013',
#     'NUM_LICENSED_BEDS': 186,
#     'NUM_STAFFED_BEDS': 131,
#     'NUM_ICU_BEDS': 16,
#     'ADULT_ICU_BEDS': 16,
#     'PEDI_ICU_BEDS': 6,
#     'BED_UTILIZATION': 0.3856949,
#     'Potential_Increase_In_Bed_Capac': 55,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.12607829999996, 'y': 40.18221950000003}},
#   {'attributes': {'OBJECTID': 598,
#     'HOSPITAL_NAME': 'Heart of the Rockies Regional Medical Center',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '1000 Rush Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Salida',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81201',
#     'COUNTY_NAME': 'Chaffee',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '015',
#     'FIPS': '08015',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 2,
#     'ADULT_ICU_BEDS': 2,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.4101918,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -106.00882469999999, 'y': 38.54315580000008}},
#   {'attributes': {'OBJECTID': 599,
#     'HOSPITAL_NAME': 'Keefe Memorial Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '602 N 6th St W',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Cheyenne Wells',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80810',
#     'COUNTY_NAME': 'Cheyenne',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '017',
#     'FIPS': '08017',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 11,
#     'NUM_ICU_BEDS': 2,
#     'ADULT_ICU_BEDS': 2,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': 0.05678705,
#     'Potential_Increase_In_Bed_Capac': 14,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -102.35549999999995, 'y': 38.82570000000004}},
#   {'attributes': {'OBJECTID': 600,
#     'HOSPITAL_NAME': 'Delta Memorial Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1501 E 3rd St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Delta',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81416',
#     'COUNTY_NAME': 'Delta',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '029',
#     'FIPS': '08029',
#     'NUM_LICENSED_BEDS': 49,
#     'NUM_STAFFED_BEDS': 49,
#     'NUM_ICU_BEDS': 6,
#     'ADULT_ICU_BEDS': 6,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.273693,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -108.04699999999997, 'y': 38.74539990000005}},
#   {'attributes': {'OBJECTID': 601,
#     'HOSPITAL_NAME': 'National Jewish Health',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1400 Jackson St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80206',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 46,
#     'NUM_STAFFED_BEDS': 24,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.02134703,
#     'Potential_Increase_In_Bed_Capac': 22,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -104.94112119999994, 'y': 39.73907360000004}},
#   {'attributes': {'OBJECTID': 602,
#     'HOSPITAL_NAME': 'Rose Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '4567 E 9th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80220',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 422,
#     'NUM_STAFFED_BEDS': 226,
#     'NUM_ICU_BEDS': 35,
#     'ADULT_ICU_BEDS': 35,
#     'PEDI_ICU_BEDS': 24,
#     'BED_UTILIZATION': 0.4880818,
#     'Potential_Increase_In_Bed_Capac': 196,
#     'AVG_VENTILATOR_USAGE': 5},
#    'geometry': {'x': -104.93404969999995, 'y': 39.73218500000007}},
#   {'attributes': {'OBJECTID': 603,
#     'HOSPITAL_NAME': 'Porter Adventist Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2525 S Downing St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80210',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 368,
#     'NUM_STAFFED_BEDS': 176,
#     'NUM_ICU_BEDS': 36,
#     'ADULT_ICU_BEDS': 36,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.5125,
#     'Potential_Increase_In_Bed_Capac': 192,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.97481949999997, 'y': 39.670038600000055}},
#   {'attributes': {'OBJECTID': 604,
#     'HOSPITAL_NAME': 'Saint Joseph Hospital (FKA Exempla St Joseph Hospital)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1375 E 19th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80218',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 400,
#     'NUM_STAFFED_BEDS': 361,
#     'NUM_ICU_BEDS': 30,
#     'ADULT_ICU_BEDS': 30,
#     'PEDI_ICU_BEDS': 35,
#     'BED_UTILIZATION': 0.6354722,
#     'Potential_Increase_In_Bed_Capac': 39,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.97172679999994, 'y': 39.74618820000006}},
#   {'attributes': {'OBJECTID': 605,
#     'HOSPITAL_NAME': 'Denver Health Main Campus',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '777 Bannock St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80204',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 555,
#     'NUM_STAFFED_BEDS': 378,
#     'NUM_ICU_BEDS': 55,
#     'ADULT_ICU_BEDS': 55,
#     'PEDI_ICU_BEDS': 25,
#     'BED_UTILIZATION': 0.6413538,
#     'Potential_Increase_In_Bed_Capac': 177,
#     'AVG_VENTILATOR_USAGE': 4},
#    'geometry': {'x': -104.99108009999998, 'y': 39.72824040000006}},
#   {'attributes': {'OBJECTID': 606,
#     'HOSPITAL_NAME': 'Presbyterian/St Lukes Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1719 E 19th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80218',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 680,
#     'NUM_STAFFED_BEDS': 307,
#     'NUM_ICU_BEDS': 71,
#     'ADULT_ICU_BEDS': 71,
#     'PEDI_ICU_BEDS': 42,
#     'BED_UTILIZATION': 0.5972095,
#     'Potential_Increase_In_Bed_Capac': 373,
#     'AVG_VENTILATOR_USAGE': 5},
#    'geometry': {'x': -104.96651689999999, 'y': 39.74704760000003}},
#   {'attributes': {'OBJECTID': 607,
#     'HOSPITAL_NAME': 'St Anthony Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '11600 W 2nd Pl',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Lakewood',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80228',
#     'COUNTY_NAME': 'Jefferson',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '059',
#     'FIPS': '08059',
#     'NUM_LICENSED_BEDS': 237,
#     'NUM_STAFFED_BEDS': 220,
#     'NUM_ICU_BEDS': 76,
#     'ADULT_ICU_BEDS': 76,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.6982939,
#     'Potential_Increase_In_Bed_Capac': 17,
#     'AVG_VENTILATOR_USAGE': 7},
#    'geometry': {'x': -105.1294246, 'y': 39.71646510000005}},
#   {'attributes': {'OBJECTID': 608,
#     'HOSPITAL_NAME': 'Parker Adventist Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '9395 Crown Crest Blvd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Parker',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80138',
#     'COUNTY_NAME': 'Douglas',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '035',
#     'FIPS': '08035',
#     'NUM_LICENSED_BEDS': 170,
#     'NUM_STAFFED_BEDS': 165,
#     'NUM_ICU_BEDS': 16,
#     'ADULT_ICU_BEDS': 16,
#     'PEDI_ICU_BEDS': 12,
#     'BED_UTILIZATION': 0.4830418,
#     'Potential_Increase_In_Bed_Capac': 5,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.77103829999999, 'y': 39.548613300000056}},
#   {'attributes': {'OBJECTID': 609,
#     'HOSPITAL_NAME': 'Vail Health (FKA Vail Valley Medical Center)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '181 W Meadow Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Vail',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81657',
#     'COUNTY_NAME': 'Eagle',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '037',
#     'FIPS': '08037',
#     'NUM_LICENSED_BEDS': 56,
#     'NUM_STAFFED_BEDS': 56,
#     'NUM_ICU_BEDS': 5,
#     'ADULT_ICU_BEDS': 5,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2490705,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -106.38226629999997, 'y': 39.64352080000003}},
#   {'attributes': {'OBJECTID': 610,
#     'HOSPITAL_NAME': 'UCHealth Memorial Hospital Central',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1400 E Boulder St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Colorado Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80909',
#     'COUNTY_NAME': 'El Paso',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '041',
#     'FIPS': '08041',
#     'NUM_LICENSED_BEDS': 583,
#     'NUM_STAFFED_BEDS': 515,
#     'NUM_ICU_BEDS': 46,
#     'ADULT_ICU_BEDS': 46,
#     'PEDI_ICU_BEDS': 84,
#     'BED_UTILIZATION': 0.6456127,
#     'Potential_Increase_In_Bed_Capac': 68,
#     'AVG_VENTILATOR_USAGE': 12},
#    'geometry': {'x': -104.79939669999999, 'y': 38.839413000000036}},
#   {'attributes': {'OBJECTID': 611,
#     'HOSPITAL_NAME': 'Penrose Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2222 N Nevada Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Colorado Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80907',
#     'COUNTY_NAME': 'El Paso',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '041',
#     'FIPS': '08041',
#     'NUM_LICENSED_BEDS': 364,
#     'NUM_STAFFED_BEDS': None,
#     'NUM_ICU_BEDS': 45,
#     'ADULT_ICU_BEDS': 45,
#     'PEDI_ICU_BEDS': 46,
#     'BED_UTILIZATION': 0.5948363,
#     'Potential_Increase_In_Bed_Capac': 364,
#     'AVG_VENTILATOR_USAGE': 9},
#    'geometry': {'x': -104.82174499999996, 'y': 38.865536700000064}},
#   {'attributes': {'OBJECTID': 612,
#     'HOSPITAL_NAME': 'St Thomas More Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '1338 Phay Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Canon City',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81212',
#     'COUNTY_NAME': 'Fremont',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '043',
#     'FIPS': '08043',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.5951781,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.22973199999996, 'y': 38.455663300000026}},
#   {'attributes': {'OBJECTID': 613,
#     'HOSPITAL_NAME': 'Valley View Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1906 Blake Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Glenwood Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81601',
#     'COUNTY_NAME': 'Garfield',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '045',
#     'FIPS': '08045',
#     'NUM_LICENSED_BEDS': 78,
#     'NUM_STAFFED_BEDS': 41,
#     'NUM_ICU_BEDS': 5,
#     'ADULT_ICU_BEDS': 5,
#     'PEDI_ICU_BEDS': 2,
#     'BED_UTILIZATION': 0.8040094,
#     'Potential_Increase_In_Bed_Capac': 37,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -107.32150509999997, 'y': 39.53249530000005}},
#   {'attributes': {'OBJECTID': 614,
#     'HOSPITAL_NAME': 'Grand River Medical Center (AKA Grand River Health)',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '501 Airport Rd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Rifle',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81650',
#     'COUNTY_NAME': 'Garfield',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '045',
#     'FIPS': '08045',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 12,
#     'NUM_ICU_BEDS': 3,
#     'ADULT_ICU_BEDS': 3,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.43379,
#     'Potential_Increase_In_Bed_Capac': 13,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -107.77000559999999, 'y': 39.521113100000036}},
#   {'attributes': {'OBJECTID': 615,
#     'HOSPITAL_NAME': 'Gunnison Valley Health',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '711 N Taylor St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Gunnison',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81230',
#     'COUNTY_NAME': 'Gunnison',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '051',
#     'FIPS': '08051',
#     'NUM_LICENSED_BEDS': 24,
#     'NUM_STAFFED_BEDS': 20,
#     'NUM_ICU_BEDS': 3,
#     'ADULT_ICU_BEDS': 3,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2334247,
#     'Potential_Increase_In_Bed_Capac': 4,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -106.92495109999999, 'y': 38.55186250000003}},
#   {'attributes': {'OBJECTID': 616,
#     'HOSPITAL_NAME': 'Spanish Peaks Regional Health Center',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '23500 Us Highway 160',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Walsenburg',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81089',
#     'COUNTY_NAME': 'Huerfano',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '055',
#     'FIPS': '08055',
#     'NUM_LICENSED_BEDS': 20,
#     'NUM_STAFFED_BEDS': 16,
#     'NUM_ICU_BEDS': 3,
#     'ADULT_ICU_BEDS': 3,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.1340753,
#     'Potential_Increase_In_Bed_Capac': 4,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.83175969999996, 'y': 37.600343800000076}},
#   {'attributes': {'OBJECTID': 617,
#     'HOSPITAL_NAME': 'St Anthony North Health Campus',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '14300 Orchard Pkwy',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Westminster',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80023',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 100,
#     'NUM_STAFFED_BEDS': 92,
#     'NUM_ICU_BEDS': 20,
#     'ADULT_ICU_BEDS': 20,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.5597975,
#     'Potential_Increase_In_Bed_Capac': 8,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.99119049999996, 'y': 39.95643730000006}},
#   {'attributes': {'OBJECTID': 618,
#     'HOSPITAL_NAME': 'Lutheran Medical Center (FKA Exempla Lutheran Medical Center)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '8300 W 38th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Wheat Ridge',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80033',
#     'COUNTY_NAME': 'Jefferson',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '059',
#     'FIPS': '08059',
#     'NUM_LICENSED_BEDS': 338,
#     'NUM_STAFFED_BEDS': 186,
#     'NUM_ICU_BEDS': 18,
#     'ADULT_ICU_BEDS': 18,
#     'PEDI_ICU_BEDS': 20,
#     'BED_UTILIZATION': 0.6358816,
#     'Potential_Increase_In_Bed_Capac': 152,
#     'AVG_VENTILATOR_USAGE': 9},
#    'geometry': {'x': -105.08989879999996, 'y': 39.76811210000005}},
#   {'attributes': {'OBJECTID': 619,
#     'HOSPITAL_NAME': 'Kit Carson County Memorial Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '286 16th St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Burlington',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80807',
#     'COUNTY_NAME': 'Kit Carson',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '063',
#     'FIPS': '08063',
#     'NUM_LICENSED_BEDS': 19,
#     'NUM_STAFFED_BEDS': 19,
#     'NUM_ICU_BEDS': 3,
#     'ADULT_ICU_BEDS': 3,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2438356,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -102.27057579999996, 'y': 39.30300650000004}},
#   {'attributes': {'OBJECTID': 620,
#     'HOSPITAL_NAME': 'St Vincent General Hospital District',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '822 W 4th St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Leadville',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80461',
#     'COUNTY_NAME': 'Lake',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '065',
#     'FIPS': '08065',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 8,
#     'NUM_ICU_BEDS': 1,
#     'ADULT_ICU_BEDS': 1,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.09486301,
#     'Potential_Increase_In_Bed_Capac': 17,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -106.30151939999996, 'y': 39.24488990000003}},
#   {'attributes': {'OBJECTID': 621,
#     'HOSPITAL_NAME': 'Animas Surgical Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '575 Rivergate Ln',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Durango',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81301',
#     'COUNTY_NAME': 'La Plata',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '067',
#     'FIPS': '08067',
#     'NUM_LICENSED_BEDS': 12,
#     'NUM_STAFFED_BEDS': 12,
#     'NUM_ICU_BEDS': 2,
#     'ADULT_ICU_BEDS': 2,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2020548,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -107.87088269999998, 'y': 37.24807060000006}},
#   {'attributes': {'OBJECTID': 622,
#     'HOSPITAL_NAME': 'Mercy Regional Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1010 Three Springs Blvd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Durango',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81301',
#     'COUNTY_NAME': 'La Plata',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '067',
#     'FIPS': '08067',
#     'NUM_LICENSED_BEDS': 82,
#     'NUM_STAFFED_BEDS': 82,
#     'NUM_ICU_BEDS': 11,
#     'ADULT_ICU_BEDS': 11,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.4490478,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -107.82556179999995, 'y': 37.23610180000003}},
#   {'attributes': {'OBJECTID': 623,
#     'HOSPITAL_NAME': 'McKee Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2000 Boise Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Loveland',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80538',
#     'COUNTY_NAME': 'Larimer',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '069',
#     'FIPS': '08069',
#     'NUM_LICENSED_BEDS': 115,
#     'NUM_STAFFED_BEDS': 115,
#     'NUM_ICU_BEDS': 11,
#     'ADULT_ICU_BEDS': 11,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2277784,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.05132809999998, 'y': 40.41323650000004}},
#   {'attributes': {'OBJECTID': 624,
#     'HOSPITAL_NAME': 'UCHealth Poudre Valley Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1024 S Lemay Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Fort Collins',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80524',
#     'COUNTY_NAME': 'Larimer',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '069',
#     'FIPS': '08069',
#     'NUM_LICENSED_BEDS': 255,
#     'NUM_STAFFED_BEDS': 225,
#     'NUM_ICU_BEDS': 12,
#     'ADULT_ICU_BEDS': 12,
#     'PEDI_ICU_BEDS': 25,
#     'BED_UTILIZATION': 0.6017778,
#     'Potential_Increase_In_Bed_Capac': 30,
#     'AVG_VENTILATOR_USAGE': 7},
#    'geometry': {'x': -105.05665469999997, 'y': 40.57164840000007}},
#   {'attributes': {'OBJECTID': 625,
#     'HOSPITAL_NAME': 'Estes Park Health (FKA Estes Park Medical Center)',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '555 Prospect Ave',
#     'HQ_ADDRESS1': 'P.O. Box 2740',
#     'HQ_CITY': 'Estes Park',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80517',
#     'COUNTY_NAME': 'Larimer',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '069',
#     'FIPS': '08069',
#     'NUM_LICENSED_BEDS': 23,
#     'NUM_STAFFED_BEDS': 23,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.1329315,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -105.51501659999997, 'y': 40.371419900000035}},
#   {'attributes': {'OBJECTID': 626,
#     'HOSPITAL_NAME': 'UCHealth Medical Center of the Rockies',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2500 Rocky Mountain Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Loveland',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80538',
#     'COUNTY_NAME': 'Larimer',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '069',
#     'FIPS': '08069',
#     'NUM_LICENSED_BEDS': 174,
#     'NUM_STAFFED_BEDS': 174,
#     'NUM_ICU_BEDS': 20,
#     'ADULT_ICU_BEDS': 20,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.763675,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 9},
#    'geometry': {'x': -104.99722109999999, 'y': 40.41578160000006}},
#   {'attributes': {'OBJECTID': 627,
#     'HOSPITAL_NAME': 'Mt San Rafael Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '410 Benedicta Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Trinidad',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81082',
#     'COUNTY_NAME': 'Las Animas',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '071',
#     'FIPS': '08071',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2870137,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -104.48756569999995, 'y': 37.17329490000003}},
#   {'attributes': {'OBJECTID': 628,
#     'HOSPITAL_NAME': 'Sterling Regional MedCenter',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '615 Fairhurst St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Sterling',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80751',
#     'COUNTY_NAME': 'Logan',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '075',
#     'FIPS': '08075',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3240548,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -103.22108429999997, 'y': 40.61239960000006}},
#   {'attributes': {'OBJECTID': 629,
#     'HOSPITAL_NAME': 'VA Western Colorado Health Care System (AKA Grand Junction VA Medical Center)',
#     'HOSPITAL_TYPE': 'VA Hospital',
#     'HQ_ADDRESS': '2121 North Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Grand Junction',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81501',
#     'COUNTY_NAME': 'Mesa',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '077',
#     'FIPS': '08077',
#     'NUM_LICENSED_BEDS': 53,
#     'NUM_STAFFED_BEDS': 53,
#     'NUM_ICU_BEDS': 1,
#     'ADULT_ICU_BEDS': 1,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -108.54101799999995, 'y': 39.07628600000004}},
#   {'attributes': {'OBJECTID': 630,
#     'HOSPITAL_NAME': 'Community Hospital (AKA Colorado West Healthcare System)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2351 G Rd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Grand Junction',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81505',
#     'COUNTY_NAME': 'Mesa',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '077',
#     'FIPS': '08077',
#     'NUM_LICENSED_BEDS': 60,
#     'NUM_STAFFED_BEDS': 53,
#     'NUM_ICU_BEDS': 12,
#     'ADULT_ICU_BEDS': 12,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3218403,
#     'Potential_Increase_In_Bed_Capac': 7,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -108.61526559999999, 'y': 39.10519720000008}},
#   {'attributes': {'OBJECTID': 631,
#     'HOSPITAL_NAME': 'St Marys Medical Center (FKA St Marys Hospital and Medical Center)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2635 N 7th St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Grand Junction',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81501',
#     'COUNTY_NAME': 'Mesa',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '077',
#     'FIPS': '08077',
#     'NUM_LICENSED_BEDS': 346,
#     'NUM_STAFFED_BEDS': 257,
#     'NUM_ICU_BEDS': 18,
#     'ADULT_ICU_BEDS': 18,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.6038484,
#     'Potential_Increase_In_Bed_Capac': 89,
#     'AVG_VENTILATOR_USAGE': 8},
#    'geometry': {'x': -108.56270549999999, 'y': 39.090481100000034}},
#   {'attributes': {'OBJECTID': 632,
#     'HOSPITAL_NAME': 'Memorial Regional Health (FKA Memorial Hospital at Craig)',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '750 Hospital Loop',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Craig',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81625',
#     'COUNTY_NAME': 'Moffat',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '081',
#     'FIPS': '08081',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3530959,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -107.58021559999997, 'y': 40.51865460000005}},
#   {'attributes': {'OBJECTID': 633,
#     'HOSPITAL_NAME': 'Southwest Memorial Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '1311 N Mildred Rd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Cortez',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81321',
#     'COUNTY_NAME': 'Montezuma',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '083',
#     'FIPS': '08083',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3845479,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -108.57460919999994, 'y': 37.36215960000004}},
#   {'attributes': {'OBJECTID': 634,
#     'HOSPITAL_NAME': 'Montrose Memorial Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '800 S 3rd St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Montrose',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81401',
#     'COUNTY_NAME': 'Montrose',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '085',
#     'FIPS': '08085',
#     'NUM_LICENSED_BEDS': 75,
#     'NUM_STAFFED_BEDS': 50,
#     'NUM_ICU_BEDS': 8,
#     'ADULT_ICU_BEDS': 8,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3665206,
#     'Potential_Increase_In_Bed_Capac': 25,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -107.86893879999997, 'y': 38.48002040000006}},
#   {'attributes': {'OBJECTID': 635,
#     'HOSPITAL_NAME': 'Colorado Plains Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1000 Lincoln St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Fort Morgan',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80701',
#     'COUNTY_NAME': 'Morgan',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '087',
#     'FIPS': '08087',
#     'NUM_LICENSED_BEDS': 50,
#     'NUM_STAFFED_BEDS': 36,
#     'NUM_ICU_BEDS': 6,
#     'ADULT_ICU_BEDS': 6,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.1456621,
#     'Potential_Increase_In_Bed_Capac': 14,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -103.79536399999995, 'y': 40.259718700000064}},
#   {'attributes': {'OBJECTID': 636,
#     'HOSPITAL_NAME': 'East Morgan County Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '2400 Edison St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Brush',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80723',
#     'COUNTY_NAME': 'Morgan',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '087',
#     'FIPS': '08087',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.1636164,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -103.64947459999996, 'y': 40.25567860000007}},
#   {'attributes': {'OBJECTID': 637,
#     'HOSPITAL_NAME': 'Arkansas Valley Regional Medical Center',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '1100 Carson Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'La Junta',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81050',
#     'COUNTY_NAME': 'Otero',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '089',
#     'FIPS': '08089',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 5,
#     'ADULT_ICU_BEDS': 5,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.4908219,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -103.54881779999994, 'y': 37.97880370000007}},
#   {'attributes': {'OBJECTID': 638,
#     'HOSPITAL_NAME': 'Melissa Memorial Hospital (AKA East Phillips County Hospital District)',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '1001 E Johnson St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Holyoke',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80734',
#     'COUNTY_NAME': 'Phillips',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '095',
#     'FIPS': '08095',
#     'NUM_LICENSED_BEDS': 15,
#     'NUM_STAFFED_BEDS': 15,
#     'NUM_ICU_BEDS': 3,
#     'ADULT_ICU_BEDS': 3,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.1926941,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -102.29029419999995, 'y': 40.57926050000003}},
#   {'attributes': {'OBJECTID': 639,
#     'HOSPITAL_NAME': 'Aspen Valley Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '401 Castle Creek Rd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Aspen',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81611',
#     'COUNTY_NAME': 'Pitkin',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '097',
#     'FIPS': '08097',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.2545753,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -106.83959369999997, 'y': 39.190544500000044}},
#   {'attributes': {'OBJECTID': 640,
#     'HOSPITAL_NAME': 'Prowers Medical Center',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '401 Kendall Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Lamar',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81052',
#     'COUNTY_NAME': 'Prowers',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '099',
#     'FIPS': '08099',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3273425,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -102.61049859999997, 'y': 38.069781300000045}},
#   {'attributes': {'OBJECTID': 641,
#     'HOSPITAL_NAME': 'St Mary-Corwin Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1008 Minnequa Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Pueblo',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81004',
#     'COUNTY_NAME': 'Pueblo',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '101',
#     'FIPS': '08101',
#     'NUM_LICENSED_BEDS': 408,
#     'NUM_STAFFED_BEDS': 42,
#     'NUM_ICU_BEDS': 6,
#     'ADULT_ICU_BEDS': 6,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.52394,
#     'Potential_Increase_In_Bed_Capac': 366,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.62398699999994, 'y': 38.23388100000005}},
#   {'attributes': {'OBJECTID': 642,
#     'HOSPITAL_NAME': 'Parkview Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '400 W 16th St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Pueblo',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81003',
#     'COUNTY_NAME': 'Pueblo',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '101',
#     'FIPS': '08101',
#     'NUM_LICENSED_BEDS': 350,
#     'NUM_STAFFED_BEDS': 276,
#     'NUM_ICU_BEDS': 11,
#     'ADULT_ICU_BEDS': 11,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.6733316,
#     'Potential_Increase_In_Bed_Capac': 74,
#     'AVG_VENTILATOR_USAGE': 9},
#    'geometry': {'x': -104.61269399999998, 'y': 38.28178310000004}},
#   {'attributes': {'OBJECTID': 643,
#     'HOSPITAL_NAME': 'Pioneers Medical Center',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '100 Pioneers Medical Center Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Meeker',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81641',
#     'COUNTY_NAME': 'Rio Blanco',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '103',
#     'FIPS': '08103',
#     'NUM_LICENSED_BEDS': 10,
#     'NUM_STAFFED_BEDS': 10,
#     'NUM_ICU_BEDS': 2,
#     'ADULT_ICU_BEDS': 2,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.4016438,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -107.88229679999995, 'y': 40.04700260000004}},
#   {'attributes': {'OBJECTID': 644,
#     'HOSPITAL_NAME': 'Rangely District Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '225 Eagle Crest St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Rangely',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81648',
#     'COUNTY_NAME': 'Rio Blanco',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '103',
#     'FIPS': '08103',
#     'NUM_LICENSED_BEDS': 25,
#     'NUM_STAFFED_BEDS': 25,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.5587945,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -108.80146479999996, 'y': 40.08319300000005}},
#   {'attributes': {'OBJECTID': 645,
#     'HOSPITAL_NAME': 'Rio Grande Hospital',
#     'HOSPITAL_TYPE': 'Critical Access Hospital',
#     'HQ_ADDRESS': '310 County Road 14',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Del Norte',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81132',
#     'COUNTY_NAME': 'Rio Grande',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '105',
#     'FIPS': '08105',
#     'NUM_LICENSED_BEDS': 17,
#     'NUM_STAFFED_BEDS': 17,
#     'NUM_ICU_BEDS': 3,
#     'ADULT_ICU_BEDS': 3,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.396938,
# ...
#     'HQ_ADDRESS': '7353 Sisters Grv',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Colorado Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80923',
#     'COUNTY_NAME': 'El Paso',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '041',
#     'FIPS': '08041',
#     'NUM_LICENSED_BEDS': 112,
#     'NUM_STAFFED_BEDS': 112,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.7011008,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.71263369999997, 'y': 38.93741190000003}},
#   {'attributes': {'OBJECTID': 5789,
#     'HOSPITAL_NAME': 'Evans Army Community Hospital',
#     'HOSPITAL_TYPE': 'Department of Defense Hospital',
#     'HQ_ADDRESS': '1650 Cochrane Cir',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Fort Carson',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80913',
#     'COUNTY_NAME': 'El Paso',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '041',
#     'FIPS': '08041',
#     'NUM_LICENSED_BEDS': 92,
#     'NUM_STAFFED_BEDS': 92,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.79691689999999, 'y': 38.720429900000056}},
#   {'attributes': {'OBJECTID': 5883,
#     'HOSPITAL_NAME': 'Wide Horizon',
#     'HOSPITAL_TYPE': 'Religious Non-Medical Health Care Institution',
#     'HQ_ADDRESS': '8900 W 38th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Wheat Ridge',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80033',
#     'COUNTY_NAME': 'Jefferson',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '059',
#     'FIPS': '08059',
#     'NUM_LICENSED_BEDS': 10,
#     'NUM_STAFFED_BEDS': 10,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.06502732,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -105.09683629999995, 'y': 39.76925320000004}},
#   {'attributes': {'OBJECTID': 5998,
#     'HOSPITAL_NAME': 'Behavioral Health Hospital for Children and Adolescents',
#     'HOSPITAL_TYPE': 'Psychiatric Hospital',
#     'HQ_ADDRESS': '8140 E 5th Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80230',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 24,
#     'NUM_STAFFED_BEDS': None,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 24,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.89421949999996, 'y': 39.72370740000008}},
#   {'attributes': {'OBJECTID': 6000,
#     'HOSPITAL_NAME': 'Boulder Community Foothills Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '4747 Arapahoe Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Boulder',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80303',
#     'COUNTY_NAME': 'Boulder',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '013',
#     'FIPS': '08013',
#     'NUM_LICENSED_BEDS': 167,
#     'NUM_STAFFED_BEDS': 139,
#     'NUM_ICU_BEDS': 18,
#     'ADULT_ICU_BEDS': 18,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.4982951,
#     'Potential_Increase_In_Bed_Capac': 28,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.23624879999994, 'y': 40.01632440000003}},
#   {'attributes': {'OBJECTID': 6055,
#     'HOSPITAL_NAME': 'Castle Rock Adventist Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '2350 Meadows Blvd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Castle Rock',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80109',
#     'COUNTY_NAME': 'Douglas',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '035',
#     'FIPS': '08035',
#     'NUM_LICENSED_BEDS': 55,
#     'NUM_STAFFED_BEDS': 53,
#     'NUM_ICU_BEDS': 8,
#     'ADULT_ICU_BEDS': 8,
#     'PEDI_ICU_BEDS': 4,
#     'BED_UTILIZATION': 0.5317136,
#     'Potential_Increase_In_Bed_Capac': 2,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -104.88710679999997, 'y': 39.40532200000007}},
#   {'attributes': {'OBJECTID': 6061,
#     'HOSPITAL_NAME': 'Encompass Health Rehabilitation Hospital of Littleton',
#     'HOSPITAL_TYPE': 'Rehabilitation Hospital',
#     'HQ_ADDRESS': '1001 W Mineral Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Littleton',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80120',
#     'COUNTY_NAME': 'Arapahoe',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '005',
#     'FIPS': '08005',
#     'NUM_LICENSED_BEDS': 40,
#     'NUM_STAFFED_BEDS': 40,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.8550708,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.99995039999999, 'y': 39.57443660000007}},
#   {'attributes': {'OBJECTID': 6065,
#     'HOSPITAL_NAME': 'Banner Fort Collins Medical Center',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '4700 Lady Moon Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Fort Collins',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80528',
#     'COUNTY_NAME': 'Larimer',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '069',
#     'FIPS': '08069',
#     'NUM_LICENSED_BEDS': 23,
#     'NUM_STAFFED_BEDS': 23,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.3459202,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.00853229999996, 'y': 40.52139000000005}},
#   {'attributes': {'OBJECTID': 6125,
#     'HOSPITAL_NAME': 'UCHealth Longs Peak Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1750 E Ken Pratt Blvd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Longmont',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80504',
#     'COUNTY_NAME': 'Boulder',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '013',
#     'FIPS': '08013',
#     'NUM_LICENSED_BEDS': 51,
#     'NUM_STAFFED_BEDS': 50,
#     'NUM_ICU_BEDS': 6,
#     'ADULT_ICU_BEDS': 6,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.489863,
#     'Potential_Increase_In_Bed_Capac': 1,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -105.06059879999998, 'y': 40.161380500000064}},
#   {'attributes': {'OBJECTID': 6126,
#     'HOSPITAL_NAME': 'VA Eastern Colorado Health Care System - Rocky Mountain Regional VA Medical Center',
#     'HOSPITAL_TYPE': 'VA Hospital',
#     'HQ_ADDRESS': '1700 N Wheeling St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Aurora',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80045',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 182,
#     'NUM_STAFFED_BEDS': 182,
#     'NUM_ICU_BEDS': 1,
#     'ADULT_ICU_BEDS': 1,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -104.83797799999996, 'y': 39.74609900000007}},
#   {'attributes': {'OBJECTID': 6225,
#     'HOSPITAL_NAME': 'UCHealth Broomfield Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '11820 Destination Dr',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Broomfield',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80021',
#     'COUNTY_NAME': 'Broomfield',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '014',
#     'FIPS': '08014',
#     'NUM_LICENSED_BEDS': 40,
#     'NUM_STAFFED_BEDS': 22,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.286924,
#     'Potential_Increase_In_Bed_Capac': 18,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -105.09145419999999, 'y': 39.91037890000007}},
#   {'attributes': {'OBJECTID': 6230,
#     'HOSPITAL_NAME': 'Denver Springs Hospital',
#     'HOSPITAL_TYPE': 'Psychiatric Hospital',
#     'HQ_ADDRESS': '8835 American Way',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Englewood',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80112',
#     'COUNTY_NAME': 'Douglas',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '035',
#     'FIPS': '08035',
#     'NUM_LICENSED_BEDS': 96,
#     'NUM_STAFFED_BEDS': 96,
#     'NUM_ICU_BEDS': 1,
#     'ADULT_ICU_BEDS': 1,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.5682363,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 1},
#    'geometry': {'x': -104.82673569999997, 'y': 39.55861130000005}},
#   {'attributes': {'OBJECTID': 6234,
#     'HOSPITAL_NAME': 'Childrens Hospital Colorado - Colorado Springs',
#     'HOSPITAL_TYPE': 'Childrens Hospital',
#     'HQ_ADDRESS': '4090 Briargate Pkwy',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Colorado Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80920',
#     'COUNTY_NAME': 'El Paso',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '041',
#     'FIPS': '08041',
#     'NUM_LICENSED_BEDS': 99,
#     'NUM_STAFFED_BEDS': None,
#     'NUM_ICU_BEDS': 35,
#     'ADULT_ICU_BEDS': 35,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 99,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -104.75454349999995, 'y': 38.96599760000004}},
#   {'attributes': {'OBJECTID': 6239,
#     'HOSPITAL_NAME': 'Clear View Behavioral Health',
#     'HOSPITAL_TYPE': 'Psychiatric Hospital',
#     'HQ_ADDRESS': '4770 Larimer Pkwy',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Johnstown',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80534',
#     'COUNTY_NAME': 'Larimer',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '069',
#     'FIPS': '08069',
#     'NUM_LICENSED_BEDS': 92,
#     'NUM_STAFFED_BEDS': 92,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.4837701,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.97530629999994, 'y': 40.40452820000007}},
#   {'attributes': {'OBJECTID': 6262,
#     'HOSPITAL_NAME': 'SCL Health Community Hospital Southwest (AKA Saint Joseph Emergency - Littleton)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '8515 W Coal Mine Ave',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Littleton',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80123',
#     'COUNTY_NAME': 'Jefferson',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '059',
#     'FIPS': '08059',
#     'NUM_LICENSED_BEDS': 8,
#     'NUM_STAFFED_BEDS': None,
#     'NUM_ICU_BEDS': 2,
#     'ADULT_ICU_BEDS': 2,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 8,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -105.09236759999999, 'y': 39.59602320000005}},
#   {'attributes': {'OBJECTID': 6263,
#     'HOSPITAL_NAME': 'SCL Health Community Hospital Aurora (AKA Saint Joseph Emergency - Aurora)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '23770 E Smoky Hill Rd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Aurora',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80016',
#     'COUNTY_NAME': 'Arapahoe',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '005',
#     'FIPS': '08005',
#     'NUM_LICENSED_BEDS': 8,
#     'NUM_STAFFED_BEDS': 8,
#     'NUM_ICU_BEDS': 1,
#     'ADULT_ICU_BEDS': 1,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.71244769999998, 'y': 39.59941020000008}},
#   {'attributes': {'OBJECTID': 6264,
#     'HOSPITAL_NAME': 'SCL Health Community Hospital Northglenn (AKA Saint Joseph Emergency - Northglenn)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '11900 Grant St',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Northglenn',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80233',
#     'COUNTY_NAME': 'Adams',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '001',
#     'FIPS': '08001',
#     'NUM_LICENSED_BEDS': 8,
#     'NUM_STAFFED_BEDS': 8,
#     'NUM_ICU_BEDS': 1,
#     'ADULT_ICU_BEDS': 1,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.98406569999997, 'y': 39.91232710000003}},
#   {'attributes': {'OBJECTID': 6283,
#     'HOSPITAL_NAME': 'UCHealth Grandview Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '5623 Pulpit Peak Vw',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Colorado Springs',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80918',
#     'COUNTY_NAME': 'El Paso',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '041',
#     'FIPS': '08041',
#     'NUM_LICENSED_BEDS': 22,
#     'NUM_STAFFED_BEDS': 22,
#     'NUM_ICU_BEDS': 4,
#     'ADULT_ICU_BEDS': 4,
#     'PEDI_ICU_BEDS': 0,
#     'BED_UTILIZATION': 0.24533,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 2},
#    'geometry': {'x': -104.81687659999994, 'y': 38.911021600000026}},
#   {'attributes': {'OBJECTID': 6285,
#     'HOSPITAL_NAME': 'UCHealth Greeley Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '6767 29th St Rd',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Greeley',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80634',
#     'COUNTY_NAME': 'Weld',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '123',
#     'FIPS': '08123',
#     'NUM_LICENSED_BEDS': 50,
#     'NUM_STAFFED_BEDS': None,
#     'NUM_ICU_BEDS': 7,
#     'ADULT_ICU_BEDS': 7,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 50,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.78999119999997, 'y': 40.39095220000007}},
#   {'attributes': {'OBJECTID': 6288,
#     'HOSPITAL_NAME': 'UCHealth Highlands Ranch Hospital',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '1500 Park Central Drive',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Highlands Ranch',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80129',
#     'COUNTY_NAME': 'Douglas',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '035',
#     'FIPS': '08035',
#     'NUM_LICENSED_BEDS': 87,
#     'NUM_STAFFED_BEDS': 87,
#     'NUM_ICU_BEDS': 15,
#     'ADULT_ICU_BEDS': 15,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': 3},
#    'geometry': {'x': -104.76574399999998, 'y': 39.54457600000006}},
#   {'attributes': {'OBJECTID': 6389,
#     'HOSPITAL_NAME': 'Eating Recovery Center - Denver',
#     'HOSPITAL_TYPE': 'Psychiatric Hospital',
#     'HQ_ADDRESS': '8190 E 1st Ave',
#     'HQ_ADDRESS1': 'Suite 105',
#     'HQ_CITY': 'Denver',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '80230',
#     'COUNTY_NAME': 'Denver',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '031',
#     'FIPS': '08031',
#     'NUM_LICENSED_BEDS': 72,
#     'NUM_STAFFED_BEDS': 24,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 48,
#     'AVG_VENTILATOR_USAGE': 0},
#    'geometry': {'x': -104.89189309999995, 'y': 39.72255370000005}},
#   {'attributes': {'OBJECTID': 6599,
#     'HOSPITAL_NAME': 'PFC James Dunn VA Clinic (AKA Pueblo VA Clinic)',
#     'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#     'HQ_ADDRESS': '4776 Eagleridge Cir',
#     'HQ_ADDRESS1': None,
#     'HQ_CITY': 'Pueblo',
#     'HQ_STATE': 'CO',
#     'HQ_ZIP_CODE': '81008',
#     'COUNTY_NAME': 'Pueblo',
#     'STATE_NAME': 'Colorado',
#     'STATE_FIPS': '08',
#     'CNTY_FIPS': '101',
#     'FIPS': '08101',
#     'NUM_LICENSED_BEDS': None,
#     'NUM_STAFFED_BEDS': None,
#     'NUM_ICU_BEDS': 0,
#     'ADULT_ICU_BEDS': 0,
#     'PEDI_ICU_BEDS': None,
#     'BED_UTILIZATION': None,
#     'Potential_Increase_In_Bed_Capac': 0,
#     'AVG_VENTILATOR_USAGE': None},
#    'geometry': {'x': -104.61935779999999, 'y': 38.322948100000076}}]}

# %%
json_simple = data['features']

# %%
json_simple
# Out:
# [{'attributes': {'OBJECTID': 585,
#    'HOSPITAL_NAME': 'Platte Valley Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1600 Prairie Center Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Brighton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80601',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 98,
#    'NUM_STAFFED_BEDS': 89,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 16,
#    'BED_UTILIZATION': 0.3365245,
#    'Potential_Increase_In_Bed_Capac': 9,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.76863899999995, 'y': 39.963935400000025}},
#  {'attributes': {'OBJECTID': 586,
#    'HOSPITAL_NAME': 'UCHealth University of Colorado Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '12605 E 16th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80045',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 698,
#    'NUM_STAFFED_BEDS': 650,
#    'NUM_ICU_BEDS': 144,
#    'ADULT_ICU_BEDS': 144,
#    'PEDI_ICU_BEDS': 50,
#    'BED_UTILIZATION': 0.8355469,
#    'Potential_Increase_In_Bed_Capac': 48,
#    'AVG_VENTILATOR_USAGE': 20},
#   'geometry': {'x': -104.84202879999998, 'y': 39.742629400000055}},
#  {'attributes': {'OBJECTID': 587,
#    'HOSPITAL_NAME': 'North Suburban Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '9191 Grant St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Thornton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80229',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 157,
#    'NUM_STAFFED_BEDS': 127,
#    'NUM_ICU_BEDS': 16,
#    'ADULT_ICU_BEDS': 16,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5709201,
#    'Potential_Increase_In_Bed_Capac': 30,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.98570889999996, 'y': 39.86355510000004}},
#  {'attributes': {'OBJECTID': 588,
#    'HOSPITAL_NAME': 'Childrens Hospital Colorado - Anschutz Medical Campus',
#    'HOSPITAL_TYPE': 'Childrens Hospital',
#    'HQ_ADDRESS': '13123 E 16th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80045',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 444,
#    'NUM_STAFFED_BEDS': 434,
#    'NUM_ICU_BEDS': 36,
#    'ADULT_ICU_BEDS': 36,
#    'PEDI_ICU_BEDS': 82,
#    'BED_UTILIZATION': 0.6275822,
#    'Potential_Increase_In_Bed_Capac': 10,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.83493109999995, 'y': 39.74224950000007}},
#  {'attributes': {'OBJECTID': 589,
#    'HOSPITAL_NAME': 'SLV Health Regional Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '106 Blanca Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Alamosa',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81101',
#    'COUNTY_NAME': 'Alamosa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '003',
#    'FIPS': '08003',
#    'NUM_LICENSED_BEDS': 49,
#    'NUM_STAFFED_BEDS': 49,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3779145,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.88288599999998, 'y': 37.47247870000007}},
#  {'attributes': {'OBJECTID': 590,
#    'HOSPITAL_NAME': 'The Medical Center of Aurora - Main Campus',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1501 S Potomac St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80012',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 346,
#    'NUM_STAFFED_BEDS': 309,
#    'NUM_ICU_BEDS': 45,
#    'ADULT_ICU_BEDS': 45,
#    'PEDI_ICU_BEDS': 14,
#    'BED_UTILIZATION': 0.6766432,
#    'Potential_Increase_In_Bed_Capac': 37,
#    'AVG_VENTILATOR_USAGE': 8},
#   'geometry': {'x': -104.83174179999997, 'y': 39.688603700000044}},
#  {'attributes': {'OBJECTID': 591,
#    'HOSPITAL_NAME': 'Swedish Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '501 E Hampden Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Englewood',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80113',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 408,
#    'NUM_STAFFED_BEDS': 327,
#    'NUM_ICU_BEDS': 58,
#    'ADULT_ICU_BEDS': 58,
#    'PEDI_ICU_BEDS': 17,
#    'BED_UTILIZATION': 0.7616182,
#    'Potential_Increase_In_Bed_Capac': 81,
#    'AVG_VENTILATOR_USAGE': 10},
#   'geometry': {'x': -104.98071769999996, 'y': 39.65417030000003}},
#  {'attributes': {'OBJECTID': 592,
#    'HOSPITAL_NAME': 'Sky Ridge Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '10101 Ridgegate Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lone Tree',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80124',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 284,
#    'NUM_STAFFED_BEDS': 284,
#    'NUM_ICU_BEDS': 30,
#    'ADULT_ICU_BEDS': 30,
#    'PEDI_ICU_BEDS': 28,
#    'BED_UTILIZATION': 0.5273714,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.87121199999996, 'y': 39.52909900000003}},
#  {'attributes': {'OBJECTID': 593,
#    'HOSPITAL_NAME': 'Littleton Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '7700 S Broadway',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Littleton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80122',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 231,
#    'NUM_STAFFED_BEDS': 159,
#    'NUM_ICU_BEDS': 24,
#    'ADULT_ICU_BEDS': 24,
#    'PEDI_ICU_BEDS': 14,
#    'BED_UTILIZATION': 0.6603946,
#    'Potential_Increase_In_Bed_Capac': 72,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.98610399999995, 'y': 39.57628840000007}},
#  {'attributes': {'OBJECTID': 594,
#    'HOSPITAL_NAME': 'Pagosa Springs Medical Center (FKA Pagosa Mountain Hospital)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '95 S Pagosa Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pagosa Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81147',
#    'COUNTY_NAME': 'Archuleta',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '007',
#    'FIPS': '08007',
#    'NUM_LICENSED_BEDS': 11,
#    'NUM_STAFFED_BEDS': 11,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2956413,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -107.07913699999995, 'y': 37.252142900000024}},
#  {'attributes': {'OBJECTID': 595,
#    'HOSPITAL_NAME': 'Good Samaritan Medical Center (FKA Exempla Good Samaritan Medical Center LLC)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '200 Exempla Cir',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lafayette',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80026',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 234,
#    'NUM_STAFFED_BEDS': 183,
#    'NUM_ICU_BEDS': 24,
#    'ADULT_ICU_BEDS': 24,
#    'PEDI_ICU_BEDS': 12,
#    'BED_UTILIZATION': 0.6969234,
#    'Potential_Increase_In_Bed_Capac': 51,
#    'AVG_VENTILATOR_USAGE': 6},
#   'geometry': {'x': -105.08652149999995, 'y': 39.970519000000024}},
#  {'attributes': {'OBJECTID': 596,
#    'HOSPITAL_NAME': 'Avista Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '100 Health Park Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Louisville',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80027',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 114,
#    'NUM_STAFFED_BEDS': 108,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 26,
#    'BED_UTILIZATION': 0.3495434,
#    'Potential_Increase_In_Bed_Capac': 6,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.15174619999999, 'y': 39.951933300000064}},
#  {'attributes': {'OBJECTID': 597,
#    'HOSPITAL_NAME': 'Longmont United Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1950 Mountain View Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Longmont',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80501',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 186,
#    'NUM_STAFFED_BEDS': 131,
#    'NUM_ICU_BEDS': 16,
#    'ADULT_ICU_BEDS': 16,
#    'PEDI_ICU_BEDS': 6,
#    'BED_UTILIZATION': 0.3856949,
#    'Potential_Increase_In_Bed_Capac': 55,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.12607829999996, 'y': 40.18221950000003}},
#  {'attributes': {'OBJECTID': 598,
#    'HOSPITAL_NAME': 'Heart of the Rockies Regional Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1000 Rush Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Salida',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81201',
#    'COUNTY_NAME': 'Chaffee',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '015',
#    'FIPS': '08015',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4101918,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.00882469999999, 'y': 38.54315580000008}},
#  {'attributes': {'OBJECTID': 599,
#    'HOSPITAL_NAME': 'Keefe Memorial Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '602 N 6th St W',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Cheyenne Wells',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80810',
#    'COUNTY_NAME': 'Cheyenne',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '017',
#    'FIPS': '08017',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 11,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': 0.05678705,
#    'Potential_Increase_In_Bed_Capac': 14,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -102.35549999999995, 'y': 38.82570000000004}},
#  {'attributes': {'OBJECTID': 600,
#    'HOSPITAL_NAME': 'Delta Memorial Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1501 E 3rd St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Delta',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81416',
#    'COUNTY_NAME': 'Delta',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '029',
#    'FIPS': '08029',
#    'NUM_LICENSED_BEDS': 49,
#    'NUM_STAFFED_BEDS': 49,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.273693,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.04699999999997, 'y': 38.74539990000005}},
#  {'attributes': {'OBJECTID': 601,
#    'HOSPITAL_NAME': 'National Jewish Health',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1400 Jackson St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80206',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 46,
#    'NUM_STAFFED_BEDS': 24,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.02134703,
#    'Potential_Increase_In_Bed_Capac': 22,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.94112119999994, 'y': 39.73907360000004}},
#  {'attributes': {'OBJECTID': 602,
#    'HOSPITAL_NAME': 'Rose Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4567 E 9th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80220',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 422,
#    'NUM_STAFFED_BEDS': 226,
#    'NUM_ICU_BEDS': 35,
#    'ADULT_ICU_BEDS': 35,
#    'PEDI_ICU_BEDS': 24,
#    'BED_UTILIZATION': 0.4880818,
#    'Potential_Increase_In_Bed_Capac': 196,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.93404969999995, 'y': 39.73218500000007}},
#  {'attributes': {'OBJECTID': 603,
#    'HOSPITAL_NAME': 'Porter Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2525 S Downing St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80210',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 368,
#    'NUM_STAFFED_BEDS': 176,
#    'NUM_ICU_BEDS': 36,
#    'ADULT_ICU_BEDS': 36,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5125,
#    'Potential_Increase_In_Bed_Capac': 192,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.97481949999997, 'y': 39.670038600000055}},
#  {'attributes': {'OBJECTID': 604,
#    'HOSPITAL_NAME': 'Saint Joseph Hospital (FKA Exempla St Joseph Hospital)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1375 E 19th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80218',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 400,
#    'NUM_STAFFED_BEDS': 361,
#    'NUM_ICU_BEDS': 30,
#    'ADULT_ICU_BEDS': 30,
#    'PEDI_ICU_BEDS': 35,
#    'BED_UTILIZATION': 0.6354722,
#    'Potential_Increase_In_Bed_Capac': 39,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.97172679999994, 'y': 39.74618820000006}},
#  {'attributes': {'OBJECTID': 605,
#    'HOSPITAL_NAME': 'Denver Health Main Campus',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '777 Bannock St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80204',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 555,
#    'NUM_STAFFED_BEDS': 378,
#    'NUM_ICU_BEDS': 55,
#    'ADULT_ICU_BEDS': 55,
#    'PEDI_ICU_BEDS': 25,
#    'BED_UTILIZATION': 0.6413538,
#    'Potential_Increase_In_Bed_Capac': 177,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.99108009999998, 'y': 39.72824040000006}},
#  {'attributes': {'OBJECTID': 606,
#    'HOSPITAL_NAME': 'Presbyterian/St Lukes Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1719 E 19th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80218',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 680,
#    'NUM_STAFFED_BEDS': 307,
#    'NUM_ICU_BEDS': 71,
#    'ADULT_ICU_BEDS': 71,
#    'PEDI_ICU_BEDS': 42,
#    'BED_UTILIZATION': 0.5972095,
#    'Potential_Increase_In_Bed_Capac': 373,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.96651689999999, 'y': 39.74704760000003}},
#  {'attributes': {'OBJECTID': 607,
#    'HOSPITAL_NAME': 'St Anthony Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '11600 W 2nd Pl',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lakewood',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80228',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 237,
#    'NUM_STAFFED_BEDS': 220,
#    'NUM_ICU_BEDS': 76,
#    'ADULT_ICU_BEDS': 76,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.6982939,
#    'Potential_Increase_In_Bed_Capac': 17,
#    'AVG_VENTILATOR_USAGE': 7},
#   'geometry': {'x': -105.1294246, 'y': 39.71646510000005}},
#  {'attributes': {'OBJECTID': 608,
#    'HOSPITAL_NAME': 'Parker Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '9395 Crown Crest Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Parker',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80138',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 170,
#    'NUM_STAFFED_BEDS': 165,
#    'NUM_ICU_BEDS': 16,
#    'ADULT_ICU_BEDS': 16,
#    'PEDI_ICU_BEDS': 12,
#    'BED_UTILIZATION': 0.4830418,
#    'Potential_Increase_In_Bed_Capac': 5,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.77103829999999, 'y': 39.548613300000056}},
#  {'attributes': {'OBJECTID': 609,
#    'HOSPITAL_NAME': 'Vail Health (FKA Vail Valley Medical Center)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '181 W Meadow Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Vail',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81657',
#    'COUNTY_NAME': 'Eagle',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '037',
#    'FIPS': '08037',
#    'NUM_LICENSED_BEDS': 56,
#    'NUM_STAFFED_BEDS': 56,
#    'NUM_ICU_BEDS': 5,
#    'ADULT_ICU_BEDS': 5,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2490705,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.38226629999997, 'y': 39.64352080000003}},
#  {'attributes': {'OBJECTID': 610,
#    'HOSPITAL_NAME': 'UCHealth Memorial Hospital Central',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1400 E Boulder St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80909',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 583,
#    'NUM_STAFFED_BEDS': 515,
#    'NUM_ICU_BEDS': 46,
#    'ADULT_ICU_BEDS': 46,
#    'PEDI_ICU_BEDS': 84,
#    'BED_UTILIZATION': 0.6456127,
#    'Potential_Increase_In_Bed_Capac': 68,
#    'AVG_VENTILATOR_USAGE': 12},
#   'geometry': {'x': -104.79939669999999, 'y': 38.839413000000036}},
#  {'attributes': {'OBJECTID': 611,
#    'HOSPITAL_NAME': 'Penrose Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2222 N Nevada Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80907',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 364,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 45,
#    'ADULT_ICU_BEDS': 45,
#    'PEDI_ICU_BEDS': 46,
#    'BED_UTILIZATION': 0.5948363,
#    'Potential_Increase_In_Bed_Capac': 364,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -104.82174499999996, 'y': 38.865536700000064}},
#  {'attributes': {'OBJECTID': 612,
#    'HOSPITAL_NAME': 'St Thomas More Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1338 Phay Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Canon City',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81212',
#    'COUNTY_NAME': 'Fremont',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '043',
#    'FIPS': '08043',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5951781,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.22973199999996, 'y': 38.455663300000026}},
#  {'attributes': {'OBJECTID': 613,
#    'HOSPITAL_NAME': 'Valley View Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1906 Blake Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Glenwood Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81601',
#    'COUNTY_NAME': 'Garfield',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '045',
#    'FIPS': '08045',
#    'NUM_LICENSED_BEDS': 78,
#    'NUM_STAFFED_BEDS': 41,
#    'NUM_ICU_BEDS': 5,
#    'ADULT_ICU_BEDS': 5,
#    'PEDI_ICU_BEDS': 2,
#    'BED_UTILIZATION': 0.8040094,
#    'Potential_Increase_In_Bed_Capac': 37,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.32150509999997, 'y': 39.53249530000005}},
#  {'attributes': {'OBJECTID': 614,
#    'HOSPITAL_NAME': 'Grand River Medical Center (AKA Grand River Health)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '501 Airport Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Rifle',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81650',
#    'COUNTY_NAME': 'Garfield',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '045',
#    'FIPS': '08045',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 12,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.43379,
#    'Potential_Increase_In_Bed_Capac': 13,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.77000559999999, 'y': 39.521113100000036}},
#  {'attributes': {'OBJECTID': 615,
#    'HOSPITAL_NAME': 'Gunnison Valley Health',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '711 N Taylor St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Gunnison',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81230',
#    'COUNTY_NAME': 'Gunnison',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '051',
#    'FIPS': '08051',
#    'NUM_LICENSED_BEDS': 24,
#    'NUM_STAFFED_BEDS': 20,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2334247,
#    'Potential_Increase_In_Bed_Capac': 4,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.92495109999999, 'y': 38.55186250000003}},
#  {'attributes': {'OBJECTID': 616,
#    'HOSPITAL_NAME': 'Spanish Peaks Regional Health Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '23500 Us Highway 160',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Walsenburg',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81089',
#    'COUNTY_NAME': 'Huerfano',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '055',
#    'FIPS': '08055',
#    'NUM_LICENSED_BEDS': 20,
#    'NUM_STAFFED_BEDS': 16,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1340753,
#    'Potential_Increase_In_Bed_Capac': 4,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.83175969999996, 'y': 37.600343800000076}},
#  {'attributes': {'OBJECTID': 617,
#    'HOSPITAL_NAME': 'St Anthony North Health Campus',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '14300 Orchard Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Westminster',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80023',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 100,
#    'NUM_STAFFED_BEDS': 92,
#    'NUM_ICU_BEDS': 20,
#    'ADULT_ICU_BEDS': 20,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5597975,
#    'Potential_Increase_In_Bed_Capac': 8,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.99119049999996, 'y': 39.95643730000006}},
#  {'attributes': {'OBJECTID': 618,
#    'HOSPITAL_NAME': 'Lutheran Medical Center (FKA Exempla Lutheran Medical Center)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '8300 W 38th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Wheat Ridge',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80033',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 338,
#    'NUM_STAFFED_BEDS': 186,
#    'NUM_ICU_BEDS': 18,
#    'ADULT_ICU_BEDS': 18,
#    'PEDI_ICU_BEDS': 20,
#    'BED_UTILIZATION': 0.6358816,
#    'Potential_Increase_In_Bed_Capac': 152,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -105.08989879999996, 'y': 39.76811210000005}},
#  {'attributes': {'OBJECTID': 619,
#    'HOSPITAL_NAME': 'Kit Carson County Memorial Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '286 16th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Burlington',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80807',
#    'COUNTY_NAME': 'Kit Carson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '063',
#    'FIPS': '08063',
#    'NUM_LICENSED_BEDS': 19,
#    'NUM_STAFFED_BEDS': 19,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2438356,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -102.27057579999996, 'y': 39.30300650000004}},
#  {'attributes': {'OBJECTID': 620,
#    'HOSPITAL_NAME': 'St Vincent General Hospital District',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '822 W 4th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Leadville',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80461',
#    'COUNTY_NAME': 'Lake',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '065',
#    'FIPS': '08065',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 8,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.09486301,
#    'Potential_Increase_In_Bed_Capac': 17,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -106.30151939999996, 'y': 39.24488990000003}},
#  {'attributes': {'OBJECTID': 621,
#    'HOSPITAL_NAME': 'Animas Surgical Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '575 Rivergate Ln',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Durango',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81301',
#    'COUNTY_NAME': 'La Plata',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '067',
#    'FIPS': '08067',
#    'NUM_LICENSED_BEDS': 12,
#    'NUM_STAFFED_BEDS': 12,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2020548,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -107.87088269999998, 'y': 37.24807060000006}},
#  {'attributes': {'OBJECTID': 622,
#    'HOSPITAL_NAME': 'Mercy Regional Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1010 Three Springs Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Durango',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81301',
#    'COUNTY_NAME': 'La Plata',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '067',
#    'FIPS': '08067',
#    'NUM_LICENSED_BEDS': 82,
#    'NUM_STAFFED_BEDS': 82,
#    'NUM_ICU_BEDS': 11,
#    'ADULT_ICU_BEDS': 11,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4490478,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.82556179999995, 'y': 37.23610180000003}},
#  {'attributes': {'OBJECTID': 623,
#    'HOSPITAL_NAME': 'McKee Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2000 Boise Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Loveland',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80538',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 115,
#    'NUM_STAFFED_BEDS': 115,
#    'NUM_ICU_BEDS': 11,
#    'ADULT_ICU_BEDS': 11,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2277784,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.05132809999998, 'y': 40.41323650000004}},
#  {'attributes': {'OBJECTID': 624,
#    'HOSPITAL_NAME': 'UCHealth Poudre Valley Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1024 S Lemay Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Collins',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80524',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 255,
#    'NUM_STAFFED_BEDS': 225,
#    'NUM_ICU_BEDS': 12,
#    'ADULT_ICU_BEDS': 12,
#    'PEDI_ICU_BEDS': 25,
#    'BED_UTILIZATION': 0.6017778,
#    'Potential_Increase_In_Bed_Capac': 30,
#    'AVG_VENTILATOR_USAGE': 7},
#   'geometry': {'x': -105.05665469999997, 'y': 40.57164840000007}},
#  {'attributes': {'OBJECTID': 625,
#    'HOSPITAL_NAME': 'Estes Park Health (FKA Estes Park Medical Center)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '555 Prospect Ave',
#    'HQ_ADDRESS1': 'P.O. Box 2740',
#    'HQ_CITY': 'Estes Park',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80517',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 23,
#    'NUM_STAFFED_BEDS': 23,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1329315,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -105.51501659999997, 'y': 40.371419900000035}},
#  {'attributes': {'OBJECTID': 626,
#    'HOSPITAL_NAME': 'UCHealth Medical Center of the Rockies',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2500 Rocky Mountain Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Loveland',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80538',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 174,
#    'NUM_STAFFED_BEDS': 174,
#    'NUM_ICU_BEDS': 20,
#    'ADULT_ICU_BEDS': 20,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.763675,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -104.99722109999999, 'y': 40.41578160000006}},
#  {'attributes': {'OBJECTID': 627,
#    'HOSPITAL_NAME': 'Mt San Rafael Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '410 Benedicta Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Trinidad',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81082',
#    'COUNTY_NAME': 'Las Animas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '071',
#    'FIPS': '08071',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2870137,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.48756569999995, 'y': 37.17329490000003}},
#  {'attributes': {'OBJECTID': 628,
#    'HOSPITAL_NAME': 'Sterling Regional MedCenter',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '615 Fairhurst St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Sterling',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80751',
#    'COUNTY_NAME': 'Logan',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '075',
#    'FIPS': '08075',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3240548,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -103.22108429999997, 'y': 40.61239960000006}},
#  {'attributes': {'OBJECTID': 629,
#    'HOSPITAL_NAME': 'VA Western Colorado Health Care System (AKA Grand Junction VA Medical Center)',
#    'HOSPITAL_TYPE': 'VA Hospital',
#    'HQ_ADDRESS': '2121 North Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Grand Junction',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81501',
#    'COUNTY_NAME': 'Mesa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '077',
#    'FIPS': '08077',
#    'NUM_LICENSED_BEDS': 53,
#    'NUM_STAFFED_BEDS': 53,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.54101799999995, 'y': 39.07628600000004}},
#  {'attributes': {'OBJECTID': 630,
#    'HOSPITAL_NAME': 'Community Hospital (AKA Colorado West Healthcare System)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2351 G Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Grand Junction',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81505',
#    'COUNTY_NAME': 'Mesa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '077',
#    'FIPS': '08077',
#    'NUM_LICENSED_BEDS': 60,
#    'NUM_STAFFED_BEDS': 53,
#    'NUM_ICU_BEDS': 12,
#    'ADULT_ICU_BEDS': 12,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3218403,
#    'Potential_Increase_In_Bed_Capac': 7,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.61526559999999, 'y': 39.10519720000008}},
#  {'attributes': {'OBJECTID': 631,
#    'HOSPITAL_NAME': 'St Marys Medical Center (FKA St Marys Hospital and Medical Center)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2635 N 7th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Grand Junction',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81501',
#    'COUNTY_NAME': 'Mesa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '077',
#    'FIPS': '08077',
#    'NUM_LICENSED_BEDS': 346,
#    'NUM_STAFFED_BEDS': 257,
#    'NUM_ICU_BEDS': 18,
#    'ADULT_ICU_BEDS': 18,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.6038484,
#    'Potential_Increase_In_Bed_Capac': 89,
#    'AVG_VENTILATOR_USAGE': 8},
#   'geometry': {'x': -108.56270549999999, 'y': 39.090481100000034}},
#  {'attributes': {'OBJECTID': 632,
#    'HOSPITAL_NAME': 'Memorial Regional Health (FKA Memorial Hospital at Craig)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '750 Hospital Loop',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Craig',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81625',
#    'COUNTY_NAME': 'Moffat',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '081',
#    'FIPS': '08081',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3530959,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.58021559999997, 'y': 40.51865460000005}},
#  {'attributes': {'OBJECTID': 633,
#    'HOSPITAL_NAME': 'Southwest Memorial Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1311 N Mildred Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Cortez',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81321',
#    'COUNTY_NAME': 'Montezuma',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '083',
#    'FIPS': '08083',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3845479,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.57460919999994, 'y': 37.36215960000004}},
#  {'attributes': {'OBJECTID': 634,
#    'HOSPITAL_NAME': 'Montrose Memorial Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '800 S 3rd St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Montrose',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81401',
#    'COUNTY_NAME': 'Montrose',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '085',
#    'FIPS': '08085',
#    'NUM_LICENSED_BEDS': 75,
#    'NUM_STAFFED_BEDS': 50,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3665206,
#    'Potential_Increase_In_Bed_Capac': 25,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.86893879999997, 'y': 38.48002040000006}},
#  {'attributes': {'OBJECTID': 635,
#    'HOSPITAL_NAME': 'Colorado Plains Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1000 Lincoln St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Morgan',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80701',
#    'COUNTY_NAME': 'Morgan',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '087',
#    'FIPS': '08087',
#    'NUM_LICENSED_BEDS': 50,
#    'NUM_STAFFED_BEDS': 36,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1456621,
#    'Potential_Increase_In_Bed_Capac': 14,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -103.79536399999995, 'y': 40.259718700000064}},
#  {'attributes': {'OBJECTID': 636,
#    'HOSPITAL_NAME': 'East Morgan County Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '2400 Edison St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Brush',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80723',
#    'COUNTY_NAME': 'Morgan',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '087',
#    'FIPS': '08087',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1636164,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -103.64947459999996, 'y': 40.25567860000007}},
#  {'attributes': {'OBJECTID': 637,
#    'HOSPITAL_NAME': 'Arkansas Valley Regional Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1100 Carson Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'La Junta',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81050',
#    'COUNTY_NAME': 'Otero',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '089',
#    'FIPS': '08089',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 5,
#    'ADULT_ICU_BEDS': 5,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4908219,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -103.54881779999994, 'y': 37.97880370000007}},
#  {'attributes': {'OBJECTID': 638,
#    'HOSPITAL_NAME': 'Melissa Memorial Hospital (AKA East Phillips County Hospital District)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1001 E Johnson St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Holyoke',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80734',
#    'COUNTY_NAME': 'Phillips',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '095',
#    'FIPS': '08095',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1926941,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -102.29029419999995, 'y': 40.57926050000003}},
#  {'attributes': {'OBJECTID': 639,
#    'HOSPITAL_NAME': 'Aspen Valley Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '401 Castle Creek Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aspen',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81611',
#    'COUNTY_NAME': 'Pitkin',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '097',
#    'FIPS': '08097',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2545753,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.83959369999997, 'y': 39.190544500000044}},
#  {'attributes': {'OBJECTID': 640,
#    'HOSPITAL_NAME': 'Prowers Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '401 Kendall Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lamar',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81052',
#    'COUNTY_NAME': 'Prowers',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '099',
#    'FIPS': '08099',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3273425,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -102.61049859999997, 'y': 38.069781300000045}},
#  {'attributes': {'OBJECTID': 641,
#    'HOSPITAL_NAME': 'St Mary-Corwin Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1008 Minnequa Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81004',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': 408,
#    'NUM_STAFFED_BEDS': 42,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.52394,
#    'Potential_Increase_In_Bed_Capac': 366,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.62398699999994, 'y': 38.23388100000005}},
#  {'attributes': {'OBJECTID': 642,
#    'HOSPITAL_NAME': 'Parkview Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '400 W 16th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81003',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': 350,
#    'NUM_STAFFED_BEDS': 276,
#    'NUM_ICU_BEDS': 11,
#    'ADULT_ICU_BEDS': 11,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.6733316,
#    'Potential_Increase_In_Bed_Capac': 74,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -104.61269399999998, 'y': 38.28178310000004}},
#  {'attributes': {'OBJECTID': 643,
#    'HOSPITAL_NAME': 'Pioneers Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '100 Pioneers Medical Center Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Meeker',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81641',
#    'COUNTY_NAME': 'Rio Blanco',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '103',
#    'FIPS': '08103',
#    'NUM_LICENSED_BEDS': 10,
#    'NUM_STAFFED_BEDS': 10,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4016438,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -107.88229679999995, 'y': 40.04700260000004}},
#  {'attributes': {'OBJECTID': 644,
#    'HOSPITAL_NAME': 'Rangely District Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '225 Eagle Crest St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Rangely',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81648',
#    'COUNTY_NAME': 'Rio Blanco',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '103',
#    'FIPS': '08103',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5587945,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -108.80146479999996, 'y': 40.08319300000005}},
#  {'attributes': {'OBJECTID': 645,
#    'HOSPITAL_NAME': 'Rio Grande Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '310 County Road 14',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Del Norte',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81132',
#    'COUNTY_NAME': 'Rio Grande',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '105',
#    'FIPS': '08105',
#    'NUM_LICENSED_BEDS': 17,
#    'NUM_STAFFED_BEDS': 17,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.396938,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.36349999999999, 'y': 37.67530000000005}},
#  {'attributes': {'OBJECTID': 646,
#    'HOSPITAL_NAME': 'UCHealth Yampa Valley Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1024 Central Park Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Steamboat Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80487',
#    'COUNTY_NAME': 'Routt',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '107',
#    'FIPS': '08107',
#    'NUM_LICENSED_BEDS': 39,
#    'NUM_STAFFED_BEDS': 39,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2238145,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.81455589999996, 'y': 40.46333690000006}},
#  {'attributes': {'OBJECTID': 647,
#    'HOSPITAL_NAME': 'St Anthony Summit Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '340 Peak One Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Frisco',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80443',
#    'COUNTY_NAME': 'Summit',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '117',
#    'FIPS': '08117',
#    'NUM_LICENSED_BEDS': 35,
#    'NUM_STAFFED_BEDS': 34,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2525383,
#    'Potential_Increase_In_Bed_Capac': 1,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.13103099999995, 'y': 39.53852800000004}},
#  {'attributes': {'OBJECTID': 648,
#    'HOSPITAL_NAME': 'UCHealth Pikes Peak Regional Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '16420 W Us Highway 24',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Woodland Park',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80863',
#    'COUNTY_NAME': 'Teller',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '119',
#    'FIPS': '08119',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2946119,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -105.07448999999997, 'y': 38.974604200000044}},
#  {'attributes': {'OBJECTID': 649,
#    'HOSPITAL_NAME': 'North Colorado Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1801 16th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Greeley',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80631',
#    'COUNTY_NAME': 'Weld',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '123',
#    'FIPS': '08123',
#    'NUM_LICENSED_BEDS': 378,
#    'NUM_STAFFED_BEDS': 225,
#    'NUM_ICU_BEDS': 26,
#    'ADULT_ICU_BEDS': 26,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5236773,
#    'Potential_Increase_In_Bed_Capac': 153,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.65224009999997, 'y': 40.41402530000005}},
#  {'attributes': {'OBJECTID': 650,
#    'HOSPITAL_NAME': 'Wray Community District Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1017 W 7th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Wray',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80758',
#    'COUNTY_NAME': 'Yuma',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '125',
#    'FIPS': '08125',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2645548,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -102.23485479999994, 'y': 40.076215500000046}},
#  {'attributes': {'OBJECTID': 651,
#    'HOSPITAL_NAME': 'Yuma District Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1000 W 8th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Yuma',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80759',
#    'COUNTY_NAME': 'Yuma',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '125',
#    'FIPS': '08125',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1068493,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -102.73703489999997, 'y': 40.12036020000005}},
#  {'attributes': {'OBJECTID': 4322,
#    'HOSPITAL_NAME': 'Colorado Mental Health Institute at Pueblo',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '1600 W 24th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81003',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': 494,
#    'NUM_STAFFED_BEDS': 452,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.948154,
#    'Potential_Increase_In_Bed_Capac': 42,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.63047839999996, 'y': 38.28957660000003}},
#  {'attributes': {'OBJECTID': 4502,
#    'HOSPITAL_NAME': 'Centennial Peaks Hospital',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '2255 S 88th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Louisville',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80027',
#    'COUNTY_NAME': 'Boulder',
# ...
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 279,
#    'NUM_STAFFED_BEDS': 279,
#    'NUM_ICU_BEDS': 49,
#    'ADULT_ICU_BEDS': 49,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.96537319999999, 'y': 39.74669800000004}},
#  {'attributes': {'OBJECTID': 5761,
#    'HOSPITAL_NAME': 'Peak View Behavioral Health',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '7353 Sisters Grv',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80923',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 112,
#    'NUM_STAFFED_BEDS': 112,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.7011008,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.71263369999997, 'y': 38.93741190000003}},
#  {'attributes': {'OBJECTID': 5789,
#    'HOSPITAL_NAME': 'Evans Army Community Hospital',
#    'HOSPITAL_TYPE': 'Department of Defense Hospital',
#    'HQ_ADDRESS': '1650 Cochrane Cir',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Carson',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80913',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 92,
#    'NUM_STAFFED_BEDS': 92,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.79691689999999, 'y': 38.720429900000056}},
#  {'attributes': {'OBJECTID': 5883,
#    'HOSPITAL_NAME': 'Wide Horizon',
#    'HOSPITAL_TYPE': 'Religious Non-Medical Health Care Institution',
#    'HQ_ADDRESS': '8900 W 38th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Wheat Ridge',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80033',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 10,
#    'NUM_STAFFED_BEDS': 10,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.06502732,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -105.09683629999995, 'y': 39.76925320000004}},
#  {'attributes': {'OBJECTID': 5998,
#    'HOSPITAL_NAME': 'Behavioral Health Hospital for Children and Adolescents',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '8140 E 5th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80230',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 24,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 24,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.89421949999996, 'y': 39.72370740000008}},
#  {'attributes': {'OBJECTID': 6000,
#    'HOSPITAL_NAME': 'Boulder Community Foothills Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4747 Arapahoe Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Boulder',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80303',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 167,
#    'NUM_STAFFED_BEDS': 139,
#    'NUM_ICU_BEDS': 18,
#    'ADULT_ICU_BEDS': 18,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4982951,
#    'Potential_Increase_In_Bed_Capac': 28,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.23624879999994, 'y': 40.01632440000003}},
#  {'attributes': {'OBJECTID': 6055,
#    'HOSPITAL_NAME': 'Castle Rock Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2350 Meadows Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Castle Rock',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80109',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 55,
#    'NUM_STAFFED_BEDS': 53,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 4,
#    'BED_UTILIZATION': 0.5317136,
#    'Potential_Increase_In_Bed_Capac': 2,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.88710679999997, 'y': 39.40532200000007}},
#  {'attributes': {'OBJECTID': 6061,
#    'HOSPITAL_NAME': 'Encompass Health Rehabilitation Hospital of Littleton',
#    'HOSPITAL_TYPE': 'Rehabilitation Hospital',
#    'HQ_ADDRESS': '1001 W Mineral Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Littleton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80120',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 40,
#    'NUM_STAFFED_BEDS': 40,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.8550708,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.99995039999999, 'y': 39.57443660000007}},
#  {'attributes': {'OBJECTID': 6065,
#    'HOSPITAL_NAME': 'Banner Fort Collins Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4700 Lady Moon Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Collins',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80528',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 23,
#    'NUM_STAFFED_BEDS': 23,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3459202,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.00853229999996, 'y': 40.52139000000005}},
#  {'attributes': {'OBJECTID': 6125,
#    'HOSPITAL_NAME': 'UCHealth Longs Peak Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1750 E Ken Pratt Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Longmont',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80504',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 51,
#    'NUM_STAFFED_BEDS': 50,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.489863,
#    'Potential_Increase_In_Bed_Capac': 1,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.06059879999998, 'y': 40.161380500000064}},
#  {'attributes': {'OBJECTID': 6126,
#    'HOSPITAL_NAME': 'VA Eastern Colorado Health Care System - Rocky Mountain Regional VA Medical Center',
#    'HOSPITAL_TYPE': 'VA Hospital',
#    'HQ_ADDRESS': '1700 N Wheeling St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80045',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 182,
#    'NUM_STAFFED_BEDS': 182,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -104.83797799999996, 'y': 39.74609900000007}},
#  {'attributes': {'OBJECTID': 6225,
#    'HOSPITAL_NAME': 'UCHealth Broomfield Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '11820 Destination Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Broomfield',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80021',
#    'COUNTY_NAME': 'Broomfield',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '014',
#    'FIPS': '08014',
#    'NUM_LICENSED_BEDS': 40,
#    'NUM_STAFFED_BEDS': 22,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.286924,
#    'Potential_Increase_In_Bed_Capac': 18,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -105.09145419999999, 'y': 39.91037890000007}},
#  {'attributes': {'OBJECTID': 6230,
#    'HOSPITAL_NAME': 'Denver Springs Hospital',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '8835 American Way',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Englewood',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80112',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 96,
#    'NUM_STAFFED_BEDS': 96,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5682363,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -104.82673569999997, 'y': 39.55861130000005}},
#  {'attributes': {'OBJECTID': 6234,
#    'HOSPITAL_NAME': 'Childrens Hospital Colorado - Colorado Springs',
#    'HOSPITAL_TYPE': 'Childrens Hospital',
#    'HQ_ADDRESS': '4090 Briargate Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80920',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 99,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 35,
#    'ADULT_ICU_BEDS': 35,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 99,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.75454349999995, 'y': 38.96599760000004}},
#  {'attributes': {'OBJECTID': 6239,
#    'HOSPITAL_NAME': 'Clear View Behavioral Health',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '4770 Larimer Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Johnstown',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80534',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 92,
#    'NUM_STAFFED_BEDS': 92,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4837701,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.97530629999994, 'y': 40.40452820000007}},
#  {'attributes': {'OBJECTID': 6262,
#    'HOSPITAL_NAME': 'SCL Health Community Hospital Southwest (AKA Saint Joseph Emergency - Littleton)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '8515 W Coal Mine Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Littleton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80123',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 8,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 8,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -105.09236759999999, 'y': 39.59602320000005}},
#  {'attributes': {'OBJECTID': 6263,
#    'HOSPITAL_NAME': 'SCL Health Community Hospital Aurora (AKA Saint Joseph Emergency - Aurora)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '23770 E Smoky Hill Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80016',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 8,
#    'NUM_STAFFED_BEDS': 8,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.71244769999998, 'y': 39.59941020000008}},
#  {'attributes': {'OBJECTID': 6264,
#    'HOSPITAL_NAME': 'SCL Health Community Hospital Northglenn (AKA Saint Joseph Emergency - Northglenn)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '11900 Grant St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Northglenn',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80233',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 8,
#    'NUM_STAFFED_BEDS': 8,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.98406569999997, 'y': 39.91232710000003}},
#  {'attributes': {'OBJECTID': 6283,
#    'HOSPITAL_NAME': 'UCHealth Grandview Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '5623 Pulpit Peak Vw',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80918',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 22,
#    'NUM_STAFFED_BEDS': 22,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.24533,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.81687659999994, 'y': 38.911021600000026}},
#  {'attributes': {'OBJECTID': 6285,
#    'HOSPITAL_NAME': 'UCHealth Greeley Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '6767 29th St Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Greeley',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80634',
#    'COUNTY_NAME': 'Weld',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '123',
#    'FIPS': '08123',
#    'NUM_LICENSED_BEDS': 50,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 7,
#    'ADULT_ICU_BEDS': 7,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 50,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.78999119999997, 'y': 40.39095220000007}},
#  {'attributes': {'OBJECTID': 6288,
#    'HOSPITAL_NAME': 'UCHealth Highlands Ranch Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1500 Park Central Drive',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Highlands Ranch',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80129',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 87,
#    'NUM_STAFFED_BEDS': 87,
#    'NUM_ICU_BEDS': 15,
#    'ADULT_ICU_BEDS': 15,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.76574399999998, 'y': 39.54457600000006}},
#  {'attributes': {'OBJECTID': 6389,
#    'HOSPITAL_NAME': 'Eating Recovery Center - Denver',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '8190 E 1st Ave',
#    'HQ_ADDRESS1': 'Suite 105',
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80230',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 72,
#    'NUM_STAFFED_BEDS': 24,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 48,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.89189309999995, 'y': 39.72255370000005}},
#  {'attributes': {'OBJECTID': 6599,
#    'HOSPITAL_NAME': 'PFC James Dunn VA Clinic (AKA Pueblo VA Clinic)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4776 Eagleridge Cir',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81008',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': None,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': None},
#   'geometry': {'x': -104.61935779999999, 'y': 38.322948100000076}}]

# %%
type(data['features'][0])
# Out:
# dict

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(json_simple)

# %%
json_simple
# Out:
# [{'attributes': {'OBJECTID': 585,
#    'HOSPITAL_NAME': 'Platte Valley Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1600 Prairie Center Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Brighton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80601',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 98,
#    'NUM_STAFFED_BEDS': 89,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 16,
#    'BED_UTILIZATION': 0.3365245,
#    'Potential_Increase_In_Bed_Capac': 9,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.76863899999995, 'y': 39.963935400000025}},
#  {'attributes': {'OBJECTID': 586,
#    'HOSPITAL_NAME': 'UCHealth University of Colorado Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '12605 E 16th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80045',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 698,
#    'NUM_STAFFED_BEDS': 650,
#    'NUM_ICU_BEDS': 144,
#    'ADULT_ICU_BEDS': 144,
#    'PEDI_ICU_BEDS': 50,
#    'BED_UTILIZATION': 0.8355469,
#    'Potential_Increase_In_Bed_Capac': 48,
#    'AVG_VENTILATOR_USAGE': 20},
#   'geometry': {'x': -104.84202879999998, 'y': 39.742629400000055}},
#  {'attributes': {'OBJECTID': 587,
#    'HOSPITAL_NAME': 'North Suburban Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '9191 Grant St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Thornton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80229',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 157,
#    'NUM_STAFFED_BEDS': 127,
#    'NUM_ICU_BEDS': 16,
#    'ADULT_ICU_BEDS': 16,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5709201,
#    'Potential_Increase_In_Bed_Capac': 30,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.98570889999996, 'y': 39.86355510000004}},
#  {'attributes': {'OBJECTID': 588,
#    'HOSPITAL_NAME': 'Childrens Hospital Colorado - Anschutz Medical Campus',
#    'HOSPITAL_TYPE': 'Childrens Hospital',
#    'HQ_ADDRESS': '13123 E 16th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80045',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 444,
#    'NUM_STAFFED_BEDS': 434,
#    'NUM_ICU_BEDS': 36,
#    'ADULT_ICU_BEDS': 36,
#    'PEDI_ICU_BEDS': 82,
#    'BED_UTILIZATION': 0.6275822,
#    'Potential_Increase_In_Bed_Capac': 10,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.83493109999995, 'y': 39.74224950000007}},
#  {'attributes': {'OBJECTID': 589,
#    'HOSPITAL_NAME': 'SLV Health Regional Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '106 Blanca Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Alamosa',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81101',
#    'COUNTY_NAME': 'Alamosa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '003',
#    'FIPS': '08003',
#    'NUM_LICENSED_BEDS': 49,
#    'NUM_STAFFED_BEDS': 49,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3779145,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.88288599999998, 'y': 37.47247870000007}},
#  {'attributes': {'OBJECTID': 590,
#    'HOSPITAL_NAME': 'The Medical Center of Aurora - Main Campus',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1501 S Potomac St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80012',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 346,
#    'NUM_STAFFED_BEDS': 309,
#    'NUM_ICU_BEDS': 45,
#    'ADULT_ICU_BEDS': 45,
#    'PEDI_ICU_BEDS': 14,
#    'BED_UTILIZATION': 0.6766432,
#    'Potential_Increase_In_Bed_Capac': 37,
#    'AVG_VENTILATOR_USAGE': 8},
#   'geometry': {'x': -104.83174179999997, 'y': 39.688603700000044}},
#  {'attributes': {'OBJECTID': 591,
#    'HOSPITAL_NAME': 'Swedish Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '501 E Hampden Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Englewood',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80113',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 408,
#    'NUM_STAFFED_BEDS': 327,
#    'NUM_ICU_BEDS': 58,
#    'ADULT_ICU_BEDS': 58,
#    'PEDI_ICU_BEDS': 17,
#    'BED_UTILIZATION': 0.7616182,
#    'Potential_Increase_In_Bed_Capac': 81,
#    'AVG_VENTILATOR_USAGE': 10},
#   'geometry': {'x': -104.98071769999996, 'y': 39.65417030000003}},
#  {'attributes': {'OBJECTID': 592,
#    'HOSPITAL_NAME': 'Sky Ridge Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '10101 Ridgegate Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lone Tree',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80124',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 284,
#    'NUM_STAFFED_BEDS': 284,
#    'NUM_ICU_BEDS': 30,
#    'ADULT_ICU_BEDS': 30,
#    'PEDI_ICU_BEDS': 28,
#    'BED_UTILIZATION': 0.5273714,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.87121199999996, 'y': 39.52909900000003}},
#  {'attributes': {'OBJECTID': 593,
#    'HOSPITAL_NAME': 'Littleton Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '7700 S Broadway',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Littleton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80122',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 231,
#    'NUM_STAFFED_BEDS': 159,
#    'NUM_ICU_BEDS': 24,
#    'ADULT_ICU_BEDS': 24,
#    'PEDI_ICU_BEDS': 14,
#    'BED_UTILIZATION': 0.6603946,
#    'Potential_Increase_In_Bed_Capac': 72,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.98610399999995, 'y': 39.57628840000007}},
#  {'attributes': {'OBJECTID': 594,
#    'HOSPITAL_NAME': 'Pagosa Springs Medical Center (FKA Pagosa Mountain Hospital)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '95 S Pagosa Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pagosa Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81147',
#    'COUNTY_NAME': 'Archuleta',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '007',
#    'FIPS': '08007',
#    'NUM_LICENSED_BEDS': 11,
#    'NUM_STAFFED_BEDS': 11,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2956413,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -107.07913699999995, 'y': 37.252142900000024}},
#  {'attributes': {'OBJECTID': 595,
#    'HOSPITAL_NAME': 'Good Samaritan Medical Center (FKA Exempla Good Samaritan Medical Center LLC)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '200 Exempla Cir',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lafayette',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80026',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 234,
#    'NUM_STAFFED_BEDS': 183,
#    'NUM_ICU_BEDS': 24,
#    'ADULT_ICU_BEDS': 24,
#    'PEDI_ICU_BEDS': 12,
#    'BED_UTILIZATION': 0.6969234,
#    'Potential_Increase_In_Bed_Capac': 51,
#    'AVG_VENTILATOR_USAGE': 6},
#   'geometry': {'x': -105.08652149999995, 'y': 39.970519000000024}},
#  {'attributes': {'OBJECTID': 596,
#    'HOSPITAL_NAME': 'Avista Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '100 Health Park Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Louisville',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80027',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 114,
#    'NUM_STAFFED_BEDS': 108,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 26,
#    'BED_UTILIZATION': 0.3495434,
#    'Potential_Increase_In_Bed_Capac': 6,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.15174619999999, 'y': 39.951933300000064}},
#  {'attributes': {'OBJECTID': 597,
#    'HOSPITAL_NAME': 'Longmont United Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1950 Mountain View Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Longmont',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80501',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 186,
#    'NUM_STAFFED_BEDS': 131,
#    'NUM_ICU_BEDS': 16,
#    'ADULT_ICU_BEDS': 16,
#    'PEDI_ICU_BEDS': 6,
#    'BED_UTILIZATION': 0.3856949,
#    'Potential_Increase_In_Bed_Capac': 55,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.12607829999996, 'y': 40.18221950000003}},
#  {'attributes': {'OBJECTID': 598,
#    'HOSPITAL_NAME': 'Heart of the Rockies Regional Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1000 Rush Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Salida',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81201',
#    'COUNTY_NAME': 'Chaffee',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '015',
#    'FIPS': '08015',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4101918,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.00882469999999, 'y': 38.54315580000008}},
#  {'attributes': {'OBJECTID': 599,
#    'HOSPITAL_NAME': 'Keefe Memorial Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '602 N 6th St W',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Cheyenne Wells',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80810',
#    'COUNTY_NAME': 'Cheyenne',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '017',
#    'FIPS': '08017',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 11,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': 0.05678705,
#    'Potential_Increase_In_Bed_Capac': 14,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -102.35549999999995, 'y': 38.82570000000004}},
#  {'attributes': {'OBJECTID': 600,
#    'HOSPITAL_NAME': 'Delta Memorial Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1501 E 3rd St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Delta',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81416',
#    'COUNTY_NAME': 'Delta',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '029',
#    'FIPS': '08029',
#    'NUM_LICENSED_BEDS': 49,
#    'NUM_STAFFED_BEDS': 49,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.273693,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.04699999999997, 'y': 38.74539990000005}},
#  {'attributes': {'OBJECTID': 601,
#    'HOSPITAL_NAME': 'National Jewish Health',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1400 Jackson St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80206',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 46,
#    'NUM_STAFFED_BEDS': 24,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.02134703,
#    'Potential_Increase_In_Bed_Capac': 22,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.94112119999994, 'y': 39.73907360000004}},
#  {'attributes': {'OBJECTID': 602,
#    'HOSPITAL_NAME': 'Rose Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4567 E 9th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80220',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 422,
#    'NUM_STAFFED_BEDS': 226,
#    'NUM_ICU_BEDS': 35,
#    'ADULT_ICU_BEDS': 35,
#    'PEDI_ICU_BEDS': 24,
#    'BED_UTILIZATION': 0.4880818,
#    'Potential_Increase_In_Bed_Capac': 196,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.93404969999995, 'y': 39.73218500000007}},
#  {'attributes': {'OBJECTID': 603,
#    'HOSPITAL_NAME': 'Porter Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2525 S Downing St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80210',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 368,
#    'NUM_STAFFED_BEDS': 176,
#    'NUM_ICU_BEDS': 36,
#    'ADULT_ICU_BEDS': 36,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5125,
#    'Potential_Increase_In_Bed_Capac': 192,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.97481949999997, 'y': 39.670038600000055}},
#  {'attributes': {'OBJECTID': 604,
#    'HOSPITAL_NAME': 'Saint Joseph Hospital (FKA Exempla St Joseph Hospital)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1375 E 19th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80218',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 400,
#    'NUM_STAFFED_BEDS': 361,
#    'NUM_ICU_BEDS': 30,
#    'ADULT_ICU_BEDS': 30,
#    'PEDI_ICU_BEDS': 35,
#    'BED_UTILIZATION': 0.6354722,
#    'Potential_Increase_In_Bed_Capac': 39,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.97172679999994, 'y': 39.74618820000006}},
#  {'attributes': {'OBJECTID': 605,
#    'HOSPITAL_NAME': 'Denver Health Main Campus',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '777 Bannock St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80204',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 555,
#    'NUM_STAFFED_BEDS': 378,
#    'NUM_ICU_BEDS': 55,
#    'ADULT_ICU_BEDS': 55,
#    'PEDI_ICU_BEDS': 25,
#    'BED_UTILIZATION': 0.6413538,
#    'Potential_Increase_In_Bed_Capac': 177,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.99108009999998, 'y': 39.72824040000006}},
#  {'attributes': {'OBJECTID': 606,
#    'HOSPITAL_NAME': 'Presbyterian/St Lukes Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1719 E 19th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80218',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 680,
#    'NUM_STAFFED_BEDS': 307,
#    'NUM_ICU_BEDS': 71,
#    'ADULT_ICU_BEDS': 71,
#    'PEDI_ICU_BEDS': 42,
#    'BED_UTILIZATION': 0.5972095,
#    'Potential_Increase_In_Bed_Capac': 373,
#    'AVG_VENTILATOR_USAGE': 5},
#   'geometry': {'x': -104.96651689999999, 'y': 39.74704760000003}},
#  {'attributes': {'OBJECTID': 607,
#    'HOSPITAL_NAME': 'St Anthony Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '11600 W 2nd Pl',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lakewood',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80228',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 237,
#    'NUM_STAFFED_BEDS': 220,
#    'NUM_ICU_BEDS': 76,
#    'ADULT_ICU_BEDS': 76,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.6982939,
#    'Potential_Increase_In_Bed_Capac': 17,
#    'AVG_VENTILATOR_USAGE': 7},
#   'geometry': {'x': -105.1294246, 'y': 39.71646510000005}},
#  {'attributes': {'OBJECTID': 608,
#    'HOSPITAL_NAME': 'Parker Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '9395 Crown Crest Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Parker',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80138',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 170,
#    'NUM_STAFFED_BEDS': 165,
#    'NUM_ICU_BEDS': 16,
#    'ADULT_ICU_BEDS': 16,
#    'PEDI_ICU_BEDS': 12,
#    'BED_UTILIZATION': 0.4830418,
#    'Potential_Increase_In_Bed_Capac': 5,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.77103829999999, 'y': 39.548613300000056}},
#  {'attributes': {'OBJECTID': 609,
#    'HOSPITAL_NAME': 'Vail Health (FKA Vail Valley Medical Center)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '181 W Meadow Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Vail',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81657',
#    'COUNTY_NAME': 'Eagle',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '037',
#    'FIPS': '08037',
#    'NUM_LICENSED_BEDS': 56,
#    'NUM_STAFFED_BEDS': 56,
#    'NUM_ICU_BEDS': 5,
#    'ADULT_ICU_BEDS': 5,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2490705,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.38226629999997, 'y': 39.64352080000003}},
#  {'attributes': {'OBJECTID': 610,
#    'HOSPITAL_NAME': 'UCHealth Memorial Hospital Central',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1400 E Boulder St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80909',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 583,
#    'NUM_STAFFED_BEDS': 515,
#    'NUM_ICU_BEDS': 46,
#    'ADULT_ICU_BEDS': 46,
#    'PEDI_ICU_BEDS': 84,
#    'BED_UTILIZATION': 0.6456127,
#    'Potential_Increase_In_Bed_Capac': 68,
#    'AVG_VENTILATOR_USAGE': 12},
#   'geometry': {'x': -104.79939669999999, 'y': 38.839413000000036}},
#  {'attributes': {'OBJECTID': 611,
#    'HOSPITAL_NAME': 'Penrose Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2222 N Nevada Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80907',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 364,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 45,
#    'ADULT_ICU_BEDS': 45,
#    'PEDI_ICU_BEDS': 46,
#    'BED_UTILIZATION': 0.5948363,
#    'Potential_Increase_In_Bed_Capac': 364,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -104.82174499999996, 'y': 38.865536700000064}},
#  {'attributes': {'OBJECTID': 612,
#    'HOSPITAL_NAME': 'St Thomas More Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1338 Phay Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Canon City',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81212',
#    'COUNTY_NAME': 'Fremont',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '043',
#    'FIPS': '08043',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5951781,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.22973199999996, 'y': 38.455663300000026}},
#  {'attributes': {'OBJECTID': 613,
#    'HOSPITAL_NAME': 'Valley View Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1906 Blake Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Glenwood Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81601',
#    'COUNTY_NAME': 'Garfield',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '045',
#    'FIPS': '08045',
#    'NUM_LICENSED_BEDS': 78,
#    'NUM_STAFFED_BEDS': 41,
#    'NUM_ICU_BEDS': 5,
#    'ADULT_ICU_BEDS': 5,
#    'PEDI_ICU_BEDS': 2,
#    'BED_UTILIZATION': 0.8040094,
#    'Potential_Increase_In_Bed_Capac': 37,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.32150509999997, 'y': 39.53249530000005}},
#  {'attributes': {'OBJECTID': 614,
#    'HOSPITAL_NAME': 'Grand River Medical Center (AKA Grand River Health)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '501 Airport Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Rifle',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81650',
#    'COUNTY_NAME': 'Garfield',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '045',
#    'FIPS': '08045',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 12,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.43379,
#    'Potential_Increase_In_Bed_Capac': 13,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.77000559999999, 'y': 39.521113100000036}},
#  {'attributes': {'OBJECTID': 615,
#    'HOSPITAL_NAME': 'Gunnison Valley Health',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '711 N Taylor St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Gunnison',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81230',
#    'COUNTY_NAME': 'Gunnison',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '051',
#    'FIPS': '08051',
#    'NUM_LICENSED_BEDS': 24,
#    'NUM_STAFFED_BEDS': 20,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2334247,
#    'Potential_Increase_In_Bed_Capac': 4,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.92495109999999, 'y': 38.55186250000003}},
#  {'attributes': {'OBJECTID': 616,
#    'HOSPITAL_NAME': 'Spanish Peaks Regional Health Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '23500 Us Highway 160',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Walsenburg',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81089',
#    'COUNTY_NAME': 'Huerfano',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '055',
#    'FIPS': '08055',
#    'NUM_LICENSED_BEDS': 20,
#    'NUM_STAFFED_BEDS': 16,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1340753,
#    'Potential_Increase_In_Bed_Capac': 4,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.83175969999996, 'y': 37.600343800000076}},
#  {'attributes': {'OBJECTID': 617,
#    'HOSPITAL_NAME': 'St Anthony North Health Campus',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '14300 Orchard Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Westminster',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80023',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 100,
#    'NUM_STAFFED_BEDS': 92,
#    'NUM_ICU_BEDS': 20,
#    'ADULT_ICU_BEDS': 20,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5597975,
#    'Potential_Increase_In_Bed_Capac': 8,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.99119049999996, 'y': 39.95643730000006}},
#  {'attributes': {'OBJECTID': 618,
#    'HOSPITAL_NAME': 'Lutheran Medical Center (FKA Exempla Lutheran Medical Center)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '8300 W 38th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Wheat Ridge',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80033',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 338,
#    'NUM_STAFFED_BEDS': 186,
#    'NUM_ICU_BEDS': 18,
#    'ADULT_ICU_BEDS': 18,
#    'PEDI_ICU_BEDS': 20,
#    'BED_UTILIZATION': 0.6358816,
#    'Potential_Increase_In_Bed_Capac': 152,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -105.08989879999996, 'y': 39.76811210000005}},
#  {'attributes': {'OBJECTID': 619,
#    'HOSPITAL_NAME': 'Kit Carson County Memorial Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '286 16th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Burlington',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80807',
#    'COUNTY_NAME': 'Kit Carson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '063',
#    'FIPS': '08063',
#    'NUM_LICENSED_BEDS': 19,
#    'NUM_STAFFED_BEDS': 19,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2438356,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -102.27057579999996, 'y': 39.30300650000004}},
#  {'attributes': {'OBJECTID': 620,
#    'HOSPITAL_NAME': 'St Vincent General Hospital District',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '822 W 4th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Leadville',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80461',
#    'COUNTY_NAME': 'Lake',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '065',
#    'FIPS': '08065',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 8,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.09486301,
#    'Potential_Increase_In_Bed_Capac': 17,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -106.30151939999996, 'y': 39.24488990000003}},
#  {'attributes': {'OBJECTID': 621,
#    'HOSPITAL_NAME': 'Animas Surgical Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '575 Rivergate Ln',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Durango',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81301',
#    'COUNTY_NAME': 'La Plata',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '067',
#    'FIPS': '08067',
#    'NUM_LICENSED_BEDS': 12,
#    'NUM_STAFFED_BEDS': 12,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2020548,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -107.87088269999998, 'y': 37.24807060000006}},
#  {'attributes': {'OBJECTID': 622,
#    'HOSPITAL_NAME': 'Mercy Regional Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1010 Three Springs Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Durango',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81301',
#    'COUNTY_NAME': 'La Plata',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '067',
#    'FIPS': '08067',
#    'NUM_LICENSED_BEDS': 82,
#    'NUM_STAFFED_BEDS': 82,
#    'NUM_ICU_BEDS': 11,
#    'ADULT_ICU_BEDS': 11,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4490478,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.82556179999995, 'y': 37.23610180000003}},
#  {'attributes': {'OBJECTID': 623,
#    'HOSPITAL_NAME': 'McKee Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2000 Boise Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Loveland',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80538',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 115,
#    'NUM_STAFFED_BEDS': 115,
#    'NUM_ICU_BEDS': 11,
#    'ADULT_ICU_BEDS': 11,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2277784,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.05132809999998, 'y': 40.41323650000004}},
#  {'attributes': {'OBJECTID': 624,
#    'HOSPITAL_NAME': 'UCHealth Poudre Valley Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1024 S Lemay Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Collins',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80524',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 255,
#    'NUM_STAFFED_BEDS': 225,
#    'NUM_ICU_BEDS': 12,
#    'ADULT_ICU_BEDS': 12,
#    'PEDI_ICU_BEDS': 25,
#    'BED_UTILIZATION': 0.6017778,
#    'Potential_Increase_In_Bed_Capac': 30,
#    'AVG_VENTILATOR_USAGE': 7},
#   'geometry': {'x': -105.05665469999997, 'y': 40.57164840000007}},
#  {'attributes': {'OBJECTID': 625,
#    'HOSPITAL_NAME': 'Estes Park Health (FKA Estes Park Medical Center)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '555 Prospect Ave',
#    'HQ_ADDRESS1': 'P.O. Box 2740',
#    'HQ_CITY': 'Estes Park',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80517',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 23,
#    'NUM_STAFFED_BEDS': 23,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1329315,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -105.51501659999997, 'y': 40.371419900000035}},
#  {'attributes': {'OBJECTID': 626,
#    'HOSPITAL_NAME': 'UCHealth Medical Center of the Rockies',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2500 Rocky Mountain Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Loveland',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80538',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 174,
#    'NUM_STAFFED_BEDS': 174,
#    'NUM_ICU_BEDS': 20,
#    'ADULT_ICU_BEDS': 20,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.763675,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -104.99722109999999, 'y': 40.41578160000006}},
#  {'attributes': {'OBJECTID': 627,
#    'HOSPITAL_NAME': 'Mt San Rafael Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '410 Benedicta Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Trinidad',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81082',
#    'COUNTY_NAME': 'Las Animas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '071',
#    'FIPS': '08071',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2870137,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.48756569999995, 'y': 37.17329490000003}},
#  {'attributes': {'OBJECTID': 628,
#    'HOSPITAL_NAME': 'Sterling Regional MedCenter',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '615 Fairhurst St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Sterling',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80751',
#    'COUNTY_NAME': 'Logan',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '075',
#    'FIPS': '08075',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3240548,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -103.22108429999997, 'y': 40.61239960000006}},
#  {'attributes': {'OBJECTID': 629,
#    'HOSPITAL_NAME': 'VA Western Colorado Health Care System (AKA Grand Junction VA Medical Center)',
#    'HOSPITAL_TYPE': 'VA Hospital',
#    'HQ_ADDRESS': '2121 North Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Grand Junction',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81501',
#    'COUNTY_NAME': 'Mesa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '077',
#    'FIPS': '08077',
#    'NUM_LICENSED_BEDS': 53,
#    'NUM_STAFFED_BEDS': 53,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.54101799999995, 'y': 39.07628600000004}},
#  {'attributes': {'OBJECTID': 630,
#    'HOSPITAL_NAME': 'Community Hospital (AKA Colorado West Healthcare System)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2351 G Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Grand Junction',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81505',
#    'COUNTY_NAME': 'Mesa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '077',
#    'FIPS': '08077',
#    'NUM_LICENSED_BEDS': 60,
#    'NUM_STAFFED_BEDS': 53,
#    'NUM_ICU_BEDS': 12,
#    'ADULT_ICU_BEDS': 12,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3218403,
#    'Potential_Increase_In_Bed_Capac': 7,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.61526559999999, 'y': 39.10519720000008}},
#  {'attributes': {'OBJECTID': 631,
#    'HOSPITAL_NAME': 'St Marys Medical Center (FKA St Marys Hospital and Medical Center)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2635 N 7th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Grand Junction',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81501',
#    'COUNTY_NAME': 'Mesa',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '077',
#    'FIPS': '08077',
#    'NUM_LICENSED_BEDS': 346,
#    'NUM_STAFFED_BEDS': 257,
#    'NUM_ICU_BEDS': 18,
#    'ADULT_ICU_BEDS': 18,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.6038484,
#    'Potential_Increase_In_Bed_Capac': 89,
#    'AVG_VENTILATOR_USAGE': 8},
#   'geometry': {'x': -108.56270549999999, 'y': 39.090481100000034}},
#  {'attributes': {'OBJECTID': 632,
#    'HOSPITAL_NAME': 'Memorial Regional Health (FKA Memorial Hospital at Craig)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '750 Hospital Loop',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Craig',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81625',
#    'COUNTY_NAME': 'Moffat',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '081',
#    'FIPS': '08081',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3530959,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.58021559999997, 'y': 40.51865460000005}},
#  {'attributes': {'OBJECTID': 633,
#    'HOSPITAL_NAME': 'Southwest Memorial Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1311 N Mildred Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Cortez',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81321',
#    'COUNTY_NAME': 'Montezuma',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '083',
#    'FIPS': '08083',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3845479,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -108.57460919999994, 'y': 37.36215960000004}},
#  {'attributes': {'OBJECTID': 634,
#    'HOSPITAL_NAME': 'Montrose Memorial Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '800 S 3rd St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Montrose',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81401',
#    'COUNTY_NAME': 'Montrose',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '085',
#    'FIPS': '08085',
#    'NUM_LICENSED_BEDS': 75,
#    'NUM_STAFFED_BEDS': 50,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3665206,
#    'Potential_Increase_In_Bed_Capac': 25,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -107.86893879999997, 'y': 38.48002040000006}},
#  {'attributes': {'OBJECTID': 635,
#    'HOSPITAL_NAME': 'Colorado Plains Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1000 Lincoln St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Morgan',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80701',
#    'COUNTY_NAME': 'Morgan',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '087',
#    'FIPS': '08087',
#    'NUM_LICENSED_BEDS': 50,
#    'NUM_STAFFED_BEDS': 36,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1456621,
#    'Potential_Increase_In_Bed_Capac': 14,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -103.79536399999995, 'y': 40.259718700000064}},
#  {'attributes': {'OBJECTID': 636,
#    'HOSPITAL_NAME': 'East Morgan County Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '2400 Edison St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Brush',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80723',
#    'COUNTY_NAME': 'Morgan',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '087',
#    'FIPS': '08087',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1636164,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -103.64947459999996, 'y': 40.25567860000007}},
#  {'attributes': {'OBJECTID': 637,
#    'HOSPITAL_NAME': 'Arkansas Valley Regional Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1100 Carson Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'La Junta',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81050',
#    'COUNTY_NAME': 'Otero',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '089',
#    'FIPS': '08089',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 5,
#    'ADULT_ICU_BEDS': 5,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4908219,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -103.54881779999994, 'y': 37.97880370000007}},
#  {'attributes': {'OBJECTID': 638,
#    'HOSPITAL_NAME': 'Melissa Memorial Hospital (AKA East Phillips County Hospital District)',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1001 E Johnson St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Holyoke',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80734',
#    'COUNTY_NAME': 'Phillips',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '095',
#    'FIPS': '08095',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1926941,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -102.29029419999995, 'y': 40.57926050000003}},
#  {'attributes': {'OBJECTID': 639,
#    'HOSPITAL_NAME': 'Aspen Valley Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '401 Castle Creek Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aspen',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81611',
#    'COUNTY_NAME': 'Pitkin',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '097',
#    'FIPS': '08097',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2545753,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.83959369999997, 'y': 39.190544500000044}},
#  {'attributes': {'OBJECTID': 640,
#    'HOSPITAL_NAME': 'Prowers Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '401 Kendall Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Lamar',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81052',
#    'COUNTY_NAME': 'Prowers',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '099',
#    'FIPS': '08099',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3273425,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -102.61049859999997, 'y': 38.069781300000045}},
#  {'attributes': {'OBJECTID': 641,
#    'HOSPITAL_NAME': 'St Mary-Corwin Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1008 Minnequa Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81004',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': 408,
#    'NUM_STAFFED_BEDS': 42,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.52394,
#    'Potential_Increase_In_Bed_Capac': 366,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.62398699999994, 'y': 38.23388100000005}},
#  {'attributes': {'OBJECTID': 642,
#    'HOSPITAL_NAME': 'Parkview Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '400 W 16th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81003',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': 350,
#    'NUM_STAFFED_BEDS': 276,
#    'NUM_ICU_BEDS': 11,
#    'ADULT_ICU_BEDS': 11,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.6733316,
#    'Potential_Increase_In_Bed_Capac': 74,
#    'AVG_VENTILATOR_USAGE': 9},
#   'geometry': {'x': -104.61269399999998, 'y': 38.28178310000004}},
#  {'attributes': {'OBJECTID': 643,
#    'HOSPITAL_NAME': 'Pioneers Medical Center',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '100 Pioneers Medical Center Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Meeker',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81641',
#    'COUNTY_NAME': 'Rio Blanco',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '103',
#    'FIPS': '08103',
#    'NUM_LICENSED_BEDS': 10,
#    'NUM_STAFFED_BEDS': 10,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4016438,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -107.88229679999995, 'y': 40.04700260000004}},
#  {'attributes': {'OBJECTID': 644,
#    'HOSPITAL_NAME': 'Rangely District Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '225 Eagle Crest St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Rangely',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81648',
#    'COUNTY_NAME': 'Rio Blanco',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '103',
#    'FIPS': '08103',
#    'NUM_LICENSED_BEDS': 25,
#    'NUM_STAFFED_BEDS': 25,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5587945,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -108.80146479999996, 'y': 40.08319300000005}},
#  {'attributes': {'OBJECTID': 645,
#    'HOSPITAL_NAME': 'Rio Grande Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '310 County Road 14',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Del Norte',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81132',
#    'COUNTY_NAME': 'Rio Grande',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '105',
#    'FIPS': '08105',
#    'NUM_LICENSED_BEDS': 17,
#    'NUM_STAFFED_BEDS': 17,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.396938,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.36349999999999, 'y': 37.67530000000005}},
#  {'attributes': {'OBJECTID': 646,
#    'HOSPITAL_NAME': 'UCHealth Yampa Valley Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1024 Central Park Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Steamboat Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80487',
#    'COUNTY_NAME': 'Routt',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '107',
#    'FIPS': '08107',
#    'NUM_LICENSED_BEDS': 39,
#    'NUM_STAFFED_BEDS': 39,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2238145,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.81455589999996, 'y': 40.46333690000006}},
#  {'attributes': {'OBJECTID': 647,
#    'HOSPITAL_NAME': 'St Anthony Summit Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '340 Peak One Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Frisco',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80443',
#    'COUNTY_NAME': 'Summit',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '117',
#    'FIPS': '08117',
#    'NUM_LICENSED_BEDS': 35,
#    'NUM_STAFFED_BEDS': 34,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2525383,
#    'Potential_Increase_In_Bed_Capac': 1,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -106.13103099999995, 'y': 39.53852800000004}},
#  {'attributes': {'OBJECTID': 648,
#    'HOSPITAL_NAME': 'UCHealth Pikes Peak Regional Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '16420 W Us Highway 24',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Woodland Park',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80863',
#    'COUNTY_NAME': 'Teller',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '119',
#    'FIPS': '08119',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2946119,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -105.07448999999997, 'y': 38.974604200000044}},
#  {'attributes': {'OBJECTID': 649,
#    'HOSPITAL_NAME': 'North Colorado Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1801 16th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Greeley',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80631',
#    'COUNTY_NAME': 'Weld',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '123',
#    'FIPS': '08123',
#    'NUM_LICENSED_BEDS': 378,
#    'NUM_STAFFED_BEDS': 225,
#    'NUM_ICU_BEDS': 26,
#    'ADULT_ICU_BEDS': 26,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5236773,
#    'Potential_Increase_In_Bed_Capac': 153,
#    'AVG_VENTILATOR_USAGE': 4},
#   'geometry': {'x': -104.65224009999997, 'y': 40.41402530000005}},
#  {'attributes': {'OBJECTID': 650,
#    'HOSPITAL_NAME': 'Wray Community District Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1017 W 7th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Wray',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80758',
#    'COUNTY_NAME': 'Yuma',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '125',
#    'FIPS': '08125',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.2645548,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -102.23485479999994, 'y': 40.076215500000046}},
#  {'attributes': {'OBJECTID': 651,
#    'HOSPITAL_NAME': 'Yuma District Hospital',
#    'HOSPITAL_TYPE': 'Critical Access Hospital',
#    'HQ_ADDRESS': '1000 W 8th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Yuma',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80759',
#    'COUNTY_NAME': 'Yuma',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '125',
#    'FIPS': '08125',
#    'NUM_LICENSED_BEDS': 15,
#    'NUM_STAFFED_BEDS': 15,
#    'NUM_ICU_BEDS': 3,
#    'ADULT_ICU_BEDS': 3,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.1068493,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -102.73703489999997, 'y': 40.12036020000005}},
#  {'attributes': {'OBJECTID': 4322,
#    'HOSPITAL_NAME': 'Colorado Mental Health Institute at Pueblo',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '1600 W 24th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81003',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': 494,
#    'NUM_STAFFED_BEDS': 452,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.948154,
#    'Potential_Increase_In_Bed_Capac': 42,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.63047839999996, 'y': 38.28957660000003}},
#  {'attributes': {'OBJECTID': 4502,
#    'HOSPITAL_NAME': 'Centennial Peaks Hospital',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '2255 S 88th St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Louisville',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80027',
#    'COUNTY_NAME': 'Boulder',
# ...
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 279,
#    'NUM_STAFFED_BEDS': 279,
#    'NUM_ICU_BEDS': 49,
#    'ADULT_ICU_BEDS': 49,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.96537319999999, 'y': 39.74669800000004}},
#  {'attributes': {'OBJECTID': 5761,
#    'HOSPITAL_NAME': 'Peak View Behavioral Health',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '7353 Sisters Grv',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80923',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 112,
#    'NUM_STAFFED_BEDS': 112,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.7011008,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.71263369999997, 'y': 38.93741190000003}},
#  {'attributes': {'OBJECTID': 5789,
#    'HOSPITAL_NAME': 'Evans Army Community Hospital',
#    'HOSPITAL_TYPE': 'Department of Defense Hospital',
#    'HQ_ADDRESS': '1650 Cochrane Cir',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Carson',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80913',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 92,
#    'NUM_STAFFED_BEDS': 92,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.79691689999999, 'y': 38.720429900000056}},
#  {'attributes': {'OBJECTID': 5883,
#    'HOSPITAL_NAME': 'Wide Horizon',
#    'HOSPITAL_TYPE': 'Religious Non-Medical Health Care Institution',
#    'HQ_ADDRESS': '8900 W 38th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Wheat Ridge',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80033',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 10,
#    'NUM_STAFFED_BEDS': 10,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.06502732,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -105.09683629999995, 'y': 39.76925320000004}},
#  {'attributes': {'OBJECTID': 5998,
#    'HOSPITAL_NAME': 'Behavioral Health Hospital for Children and Adolescents',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '8140 E 5th Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80230',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 24,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 24,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.89421949999996, 'y': 39.72370740000008}},
#  {'attributes': {'OBJECTID': 6000,
#    'HOSPITAL_NAME': 'Boulder Community Foothills Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4747 Arapahoe Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Boulder',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80303',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 167,
#    'NUM_STAFFED_BEDS': 139,
#    'NUM_ICU_BEDS': 18,
#    'ADULT_ICU_BEDS': 18,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4982951,
#    'Potential_Increase_In_Bed_Capac': 28,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.23624879999994, 'y': 40.01632440000003}},
#  {'attributes': {'OBJECTID': 6055,
#    'HOSPITAL_NAME': 'Castle Rock Adventist Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '2350 Meadows Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Castle Rock',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80109',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 55,
#    'NUM_STAFFED_BEDS': 53,
#    'NUM_ICU_BEDS': 8,
#    'ADULT_ICU_BEDS': 8,
#    'PEDI_ICU_BEDS': 4,
#    'BED_UTILIZATION': 0.5317136,
#    'Potential_Increase_In_Bed_Capac': 2,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.88710679999997, 'y': 39.40532200000007}},
#  {'attributes': {'OBJECTID': 6061,
#    'HOSPITAL_NAME': 'Encompass Health Rehabilitation Hospital of Littleton',
#    'HOSPITAL_TYPE': 'Rehabilitation Hospital',
#    'HQ_ADDRESS': '1001 W Mineral Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Littleton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80120',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 40,
#    'NUM_STAFFED_BEDS': 40,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.8550708,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.99995039999999, 'y': 39.57443660000007}},
#  {'attributes': {'OBJECTID': 6065,
#    'HOSPITAL_NAME': 'Banner Fort Collins Medical Center',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4700 Lady Moon Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Fort Collins',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80528',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 23,
#    'NUM_STAFFED_BEDS': 23,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.3459202,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.00853229999996, 'y': 40.52139000000005}},
#  {'attributes': {'OBJECTID': 6125,
#    'HOSPITAL_NAME': 'UCHealth Longs Peak Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1750 E Ken Pratt Blvd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Longmont',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80504',
#    'COUNTY_NAME': 'Boulder',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '013',
#    'FIPS': '08013',
#    'NUM_LICENSED_BEDS': 51,
#    'NUM_STAFFED_BEDS': 50,
#    'NUM_ICU_BEDS': 6,
#    'ADULT_ICU_BEDS': 6,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.489863,
#    'Potential_Increase_In_Bed_Capac': 1,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -105.06059879999998, 'y': 40.161380500000064}},
#  {'attributes': {'OBJECTID': 6126,
#    'HOSPITAL_NAME': 'VA Eastern Colorado Health Care System - Rocky Mountain Regional VA Medical Center',
#    'HOSPITAL_TYPE': 'VA Hospital',
#    'HQ_ADDRESS': '1700 N Wheeling St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80045',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 182,
#    'NUM_STAFFED_BEDS': 182,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -104.83797799999996, 'y': 39.74609900000007}},
#  {'attributes': {'OBJECTID': 6225,
#    'HOSPITAL_NAME': 'UCHealth Broomfield Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '11820 Destination Dr',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Broomfield',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80021',
#    'COUNTY_NAME': 'Broomfield',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '014',
#    'FIPS': '08014',
#    'NUM_LICENSED_BEDS': 40,
#    'NUM_STAFFED_BEDS': 22,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.286924,
#    'Potential_Increase_In_Bed_Capac': 18,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -105.09145419999999, 'y': 39.91037890000007}},
#  {'attributes': {'OBJECTID': 6230,
#    'HOSPITAL_NAME': 'Denver Springs Hospital',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '8835 American Way',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Englewood',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80112',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 96,
#    'NUM_STAFFED_BEDS': 96,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.5682363,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 1},
#   'geometry': {'x': -104.82673569999997, 'y': 39.55861130000005}},
#  {'attributes': {'OBJECTID': 6234,
#    'HOSPITAL_NAME': 'Childrens Hospital Colorado - Colorado Springs',
#    'HOSPITAL_TYPE': 'Childrens Hospital',
#    'HQ_ADDRESS': '4090 Briargate Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80920',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 99,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 35,
#    'ADULT_ICU_BEDS': 35,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 99,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.75454349999995, 'y': 38.96599760000004}},
#  {'attributes': {'OBJECTID': 6239,
#    'HOSPITAL_NAME': 'Clear View Behavioral Health',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '4770 Larimer Pkwy',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Johnstown',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80534',
#    'COUNTY_NAME': 'Larimer',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '069',
#    'FIPS': '08069',
#    'NUM_LICENSED_BEDS': 92,
#    'NUM_STAFFED_BEDS': 92,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.4837701,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.97530629999994, 'y': 40.40452820000007}},
#  {'attributes': {'OBJECTID': 6262,
#    'HOSPITAL_NAME': 'SCL Health Community Hospital Southwest (AKA Saint Joseph Emergency - Littleton)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '8515 W Coal Mine Ave',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Littleton',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80123',
#    'COUNTY_NAME': 'Jefferson',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '059',
#    'FIPS': '08059',
#    'NUM_LICENSED_BEDS': 8,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 2,
#    'ADULT_ICU_BEDS': 2,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 8,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -105.09236759999999, 'y': 39.59602320000005}},
#  {'attributes': {'OBJECTID': 6263,
#    'HOSPITAL_NAME': 'SCL Health Community Hospital Aurora (AKA Saint Joseph Emergency - Aurora)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '23770 E Smoky Hill Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Aurora',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80016',
#    'COUNTY_NAME': 'Arapahoe',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '005',
#    'FIPS': '08005',
#    'NUM_LICENSED_BEDS': 8,
#    'NUM_STAFFED_BEDS': 8,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.71244769999998, 'y': 39.59941020000008}},
#  {'attributes': {'OBJECTID': 6264,
#    'HOSPITAL_NAME': 'SCL Health Community Hospital Northglenn (AKA Saint Joseph Emergency - Northglenn)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '11900 Grant St',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Northglenn',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80233',
#    'COUNTY_NAME': 'Adams',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '001',
#    'FIPS': '08001',
#    'NUM_LICENSED_BEDS': 8,
#    'NUM_STAFFED_BEDS': 8,
#    'NUM_ICU_BEDS': 1,
#    'ADULT_ICU_BEDS': 1,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.98406569999997, 'y': 39.91232710000003}},
#  {'attributes': {'OBJECTID': 6283,
#    'HOSPITAL_NAME': 'UCHealth Grandview Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '5623 Pulpit Peak Vw',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Colorado Springs',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80918',
#    'COUNTY_NAME': 'El Paso',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '041',
#    'FIPS': '08041',
#    'NUM_LICENSED_BEDS': 22,
#    'NUM_STAFFED_BEDS': 22,
#    'NUM_ICU_BEDS': 4,
#    'ADULT_ICU_BEDS': 4,
#    'PEDI_ICU_BEDS': 0,
#    'BED_UTILIZATION': 0.24533,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 2},
#   'geometry': {'x': -104.81687659999994, 'y': 38.911021600000026}},
#  {'attributes': {'OBJECTID': 6285,
#    'HOSPITAL_NAME': 'UCHealth Greeley Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '6767 29th St Rd',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Greeley',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80634',
#    'COUNTY_NAME': 'Weld',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '123',
#    'FIPS': '08123',
#    'NUM_LICENSED_BEDS': 50,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 7,
#    'ADULT_ICU_BEDS': 7,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 50,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.78999119999997, 'y': 40.39095220000007}},
#  {'attributes': {'OBJECTID': 6288,
#    'HOSPITAL_NAME': 'UCHealth Highlands Ranch Hospital',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '1500 Park Central Drive',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Highlands Ranch',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80129',
#    'COUNTY_NAME': 'Douglas',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '035',
#    'FIPS': '08035',
#    'NUM_LICENSED_BEDS': 87,
#    'NUM_STAFFED_BEDS': 87,
#    'NUM_ICU_BEDS': 15,
#    'ADULT_ICU_BEDS': 15,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': 3},
#   'geometry': {'x': -104.76574399999998, 'y': 39.54457600000006}},
#  {'attributes': {'OBJECTID': 6389,
#    'HOSPITAL_NAME': 'Eating Recovery Center - Denver',
#    'HOSPITAL_TYPE': 'Psychiatric Hospital',
#    'HQ_ADDRESS': '8190 E 1st Ave',
#    'HQ_ADDRESS1': 'Suite 105',
#    'HQ_CITY': 'Denver',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '80230',
#    'COUNTY_NAME': 'Denver',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '031',
#    'FIPS': '08031',
#    'NUM_LICENSED_BEDS': 72,
#    'NUM_STAFFED_BEDS': 24,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 48,
#    'AVG_VENTILATOR_USAGE': 0},
#   'geometry': {'x': -104.89189309999995, 'y': 39.72255370000005}},
#  {'attributes': {'OBJECTID': 6599,
#    'HOSPITAL_NAME': 'PFC James Dunn VA Clinic (AKA Pueblo VA Clinic)',
#    'HOSPITAL_TYPE': 'Short Term Acute Care Hospital',
#    'HQ_ADDRESS': '4776 Eagleridge Cir',
#    'HQ_ADDRESS1': None,
#    'HQ_CITY': 'Pueblo',
#    'HQ_STATE': 'CO',
#    'HQ_ZIP_CODE': '81008',
#    'COUNTY_NAME': 'Pueblo',
#    'STATE_NAME': 'Colorado',
#    'STATE_FIPS': '08',
#    'CNTY_FIPS': '101',
#    'FIPS': '08101',
#    'NUM_LICENSED_BEDS': None,
#    'NUM_STAFFED_BEDS': None,
#    'NUM_ICU_BEDS': 0,
#    'ADULT_ICU_BEDS': 0,
#    'PEDI_ICU_BEDS': None,
#    'BED_UTILIZATION': None,
#    'Potential_Increase_In_Bed_Capac': 0,
#    'AVG_VENTILATOR_USAGE': None},
#   'geometry': {'x': -104.61935779999999, 'y': 38.322948100000076}}]

# %%
new_list_of_dicts = [
    x['attributes'] for x in json_simple
]

# %%
data_f = pd.DataFrame(new_list_of_dicts)

# %%
data_f.index.name = 'id'

# %%
data_f.index.name
# Out:
# 'id'

# %%
output_csv = pd.DataFrame.to_csv(data_f)

# %%
output_csv
# Out:
# 'id,OBJECTID,HOSPITAL_NAME,HOSPITAL_TYPE,HQ_ADDRESS,HQ_ADDRESS1,HQ_CITY,HQ_STATE,HQ_ZIP_CODE,COUNTY_NAME,STATE_NAME,STATE_FIPS,CNTY_FIPS,FIPS,NUM_LICENSED_BEDS,NUM_STAFFED_BEDS,NUM_ICU_BEDS,ADULT_ICU_BEDS,PEDI_ICU_BEDS,BED_UTILIZATION,Potential_Increase_In_Bed_Capac,AVG_VENTILATOR_USAGE\r\n0,585,Platte Valley Medical Center,Short Term Acute Care Hospital,1600 Prairie Center Pkwy,,Brighton,CO,80601,Adams,Colorado,08,001,08001,98.0,89.0,8,8,16.0,0.3365245,9,2.0\r\n1,586,UCHealth University of Colorado Hospital,Short Term Acute Care Hospital,12605 E 16th Ave,,Aurora,CO,80045,Adams,Colorado,08,001,08001,698.0,650.0,144,144,50.0,0.8355469,48,20.0\r\n2,587,North Suburban Medical Center,Short Term Acute Care Hospital,9191 Grant St,,Thornton,CO,80229,Adams,Colorado,08,001,08001,157.0,127.0,16,16,0.0,0.5709201,30,5.0\r\n3,588,Childrens Hospital Colorado - Anschutz Medical Campus,Childrens Hospital,13123 E 16th Ave,,Aurora,CO,80045,Adams,Colorado,08,001,08001,444.0,434.0,36,36,82.0,0.6275822,10,5.0\r\n4,589,SLV Health Regional Medical Center,Short Term Acute Care Hospital,106 Blanca Ave,,Alamosa,CO,81101,Alamosa,Colorado,08,003,08003,49.0,49.0,6,6,0.0,0.3779145,0,2.0\r\n5,590,The Medical Center of Aurora - Main Campus,Short Term Acute Care Hospital,1501 S Potomac St,,Aurora,CO,80012,Arapahoe,Colorado,08,005,08005,346.0,309.0,45,45,14.0,0.6766432,37,8.0\r\n6,591,Swedish Medical Center,Short Term Acute Care Hospital,501 E Hampden Ave,,Englewood,CO,80113,Arapahoe,Colorado,08,005,08005,408.0,327.0,58,58,17.0,0.7616182,81,10.0\r\n7,592,Sky Ridge Medical Center,Short Term Acute Care Hospital,10101 Ridgegate Pkwy,,Lone Tree,CO,80124,Douglas,Colorado,08,035,08035,284.0,284.0,30,30,28.0,0.5273714,0,4.0\r\n8,593,Littleton Adventist Hospital,Short Term Acute Care Hospital,7700 S Broadway,,Littleton,CO,80122,Arapahoe,Colorado,08,005,08005,231.0,159.0,24,24,14.0,0.6603946,72,4.0\r\n9,594,Pagosa Springs Medical Center (FKA Pagosa Mountain Hospital),Critical Access Hospital,95 S Pagosa Blvd,,Pagosa Springs,CO,81147,Archuleta,Colorado,08,007,08007,11.0,11.0,2,2,0.0,0.2956413,0,1.0\r\n10,595,Good Samaritan Medical Center (FKA Exempla Good Samaritan Medical Center LLC),Short Term Acute Care Hospital,200 Exempla Cir,,Lafayette,CO,80026,Boulder,Colorado,08,013,08013,234.0,183.0,24,24,12.0,0.6969234,51,6.0\r\n11,596,Avista Adventist Hospital,Short Term Acute Care Hospital,100 Health Park Dr,,Louisville,CO,80027,Boulder,Colorado,08,013,08013,114.0,108.0,8,8,26.0,0.3495434,6,2.0\r\n12,597,Longmont United Hospital,Short Term Acute Care Hospital,1950 Mountain View Ave,,Longmont,CO,80501,Boulder,Colorado,08,013,08013,186.0,131.0,16,16,6.0,0.3856949,55,2.0\r\n13,598,Heart of the Rockies Regional Medical Center,Critical Access Hospital,1000 Rush Dr,,Salida,CO,81201,Chaffee,Colorado,08,015,08015,25.0,25.0,2,2,0.0,0.4101918,0,2.0\r\n14,599,Keefe Memorial Hospital,Short Term Acute Care Hospital,602 N 6th St W,,Cheyenne Wells,CO,80810,Cheyenne,Colorado,08,017,08017,25.0,11.0,2,2,,0.05678705,14,1.0\r\n15,600,Delta Memorial Hospital,Short Term Acute Care Hospital,1501 E 3rd St,,Delta,CO,81416,Delta,Colorado,08,029,08029,49.0,49.0,6,6,0.0,0.273693,0,2.0\r\n16,601,National Jewish Health,Short Term Acute Care Hospital,1400 Jackson St,,Denver,CO,80206,Denver,Colorado,08,031,08031,46.0,24.0,4,4,0.0,0.02134703,22,2.0\r\n17,602,Rose Medical Center,Short Term Acute Care Hospital,4567 E 9th Ave,,Denver,CO,80220,Denver,Colorado,08,031,08031,422.0,226.0,35,35,24.0,0.4880818,196,5.0\r\n18,603,Porter Adventist Hospital,Short Term Acute Care Hospital,2525 S Downing St,,Denver,CO,80210,Denver,Colorado,08,031,08031,368.0,176.0,36,36,0.0,0.5125,192,3.0\r\n19,604,Saint Joseph Hospital (FKA Exempla St Joseph Hospital),Short Term Acute Care Hospital,1375 E 19th Ave,,Denver,CO,80218,Denver,Colorado,08,031,08031,400.0,361.0,30,30,35.0,0.6354722,39,3.0\r\n20,605,Denver Health Main Campus,Short Term Acute Care Hospital,777 Bannock St,,Denver,CO,80204,Denver,Colorado,08,031,08031,555.0,378.0,55 ...

# %%
output_csv = data_f.to_csv('hospital-data.csv')
